# %%
import json
import math
import re
import time
from datetime import datetime
from string import punctuation, whitespace
from IPython.display import clear_output
import emoji
import numpy as np
import pandas as pd
from natasha import (PER, Doc, MorphVocab, NamesExtractor, NewsEmbedding,
                     NewsMorphTagger, NewsNERTagger, NewsSyntaxParser,
                     Segmenter)
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from dostoevsky.tokenization import RegexTokenizer
from dostoevsky.models import FastTextSocialNetworkModel
import pickle

# %%
df_raw = pd.read_csv("./reviews_cleaned.csv")
df_raw
# Out:
#       Unnamed: 0                                   review_full_text  \
# 0              0  Взяла эти ящики для рассады и не пожалела.  Пл...
# 1              1  Отличные ящики, к качеству и упаковке претензи...
# 2              2  Быстрая доставка , все цело. И подарок положил...
# 3              3  Ящики отличные, крепкие, маленький презент вну...
# 4              4  Очень хорошие ящики, уже с отверстиями для вод...
# ...          ...                                                ...
# 3283        3283  Ужасная лампа. Греет очень сильно. Надолго вкл...
# 3284        3284  Лампа в принципе не плохая,но с ДНаТ сложно ко...
# 3285        3285  Очень сильно греется, нагревается буквально за...
# 3286        3286  заказывал на 200вт. измерил, показывала 80 вт,...
# 3287        3287  На 50в даже близко нет,не замеряли, есть прост...
#
#       review_rating                                            product  \
# 0               5.0  Мастерская Elbrus / Балконные ящики для цветов...
# 1               5.0  Мастерская Elbrus / Балконные ящики для цветов...
# 2               5.0  Мастерская Elbrus / Балконные ящики для цветов...
# 3               5.0  Мастерская Elbrus / Балконные ящики для цветов...
# 4               5.0  Мастерская Elbrus / Балконные ящики для цветов...
# ...             ...                                                ...
# 3283            1.0  HOUSEFLOW / Фитолампа для растений и рассады п...
# 3284            3.0  HOUSEFLOW / Фитолампа для растений и рассады п...
# 3285            3.0  HOUSEFLOW / Фитолампа для растений и рассады п...
# 3286            2.0  HOUSEFLOW / Фитолампа для растений и рассады п...
# 3287            2.0  HOUSEFLOW / Фитолампа для растений и рассады п...
#
#                                                category  \
# 0     Сад и дача / Горшки, опоры и все для рассады /...
# 1     Сад и дача / Горшки, опоры и все для рассады /...
# 2     Сад и дача / Горшки, опоры и все для рассады /...
# 3     Сад и дача / Горшки, опоры и все для рассады /...
# 4     Сад и дача / Горшки, опоры и все для рассады /...
# ...                                                 ...
# 3283  Сад и дача / Горшки, опоры и все для рассады /...
# 3284  Сад и дача / Горшки, опоры и все для рассады /...
# 3285  Сад и дача / Горшки, опоры и все для рассады /...
# 3286  Сад и дача / Горшки, опоры и все для рассады /...
# 3287  Сад и дача / Горшки, опоры и все для рассады /...
#
#                                                     url  \
# 0     https://www.wildberries.ru/catalog/144230143/f...
# 1     https://www.wildberries.ru/catalog/144230143/f...
# 2     https://www.wildberries.ru/catalog/144230143/f...
# 3     https://www.wildberries.ru/catalog/144230143/f...
# 4     https://www.wildberries.ru/catalog/144230143/f...
# ...                                                 ...
# 3283  https://www.wildberries.ru/catalog/166226613/f...
# 3284  https://www.wildberries.ru/catalog/166226613/f...
# 3285  https://www.wildberries.ru/catalog/166226613/f...
# 3286  https://www.wildberries.ru/catalog/166226613/f...
# 3287  https://www.wildberries.ru/catalog/166226613/f...
#
#      review_full_text_marked
# 0                   Unmarked
# 1                   Unmarked
# 2                   Unmarked
# 3                   Unmarked
# 4                   Unmarked
# ...                      ...
# 3283                Unmarked
# 3284                Unmarked
# 3285                Unmarked
# 3286                Unmarked
# 3287                Unmarked
#
# [3288 rows x 7 columns]

# %%
stopwords_ru = stopwords.words("russian")
segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

# %%
def get_syntax(df, row, text_cell = "text"):
    res = []
    
    def recursive(df, row, res, text_cell):
        edges = df[(df["head_id"]==row["id"])]
        edges = edges[(edges["id"] != edges["head_id"])]
        if edges.empty:
            if re.search(fr"[{punctuation}]", row[text_cell]):
                return
            res.append((row[text_cell], row["rel"], row["pos"], row["lemma"]))
            return
        
        isPrinted = False
        for index, edge in edges.iterrows():
            if edge["rel"] == "conj":
                continue
            if text_cell == "lemma":
                if edge["text"] in stopwords_ru or re.search(fr"\d|[{punctuation}]", edge["text"]):
                    continue
            if int(edge["id"].split("_")[1]) > int(row["id"].split("_")[1]) and not isPrinted:
                res.append((row[text_cell], row["rel"], row["pos"], row["lemma"]))
                isPrinted = True
            recursive(df, edge, res, text_cell)
        if not isPrinted:
            res.append((row[text_cell], row["rel"], row["pos"], row["lemma"]))
            isPrinted = True
    
    recursive(df,row, res, text_cell)
    texts = [x[0] for x in res]
    texts = re.sub(r'\s([?.!,;:"](?:\s|$))', r'\1', " ".join(texts))
    rels = [x[1] for x in res]
    poses = [x[2] for x in res]
    lemmas = [x[3] for x in res]
    return texts, rels, poses, lemmas

# %%
numpy_data = df_raw.to_numpy()

# %%
black_list = ["спасибо", "доставка", "продавец", "покупка",
              "хороший", "отличный", "очень",
              "прийти"] + stopwords_ru

# %%
def isPos(data, pos, black_list = black_list):
    indices = [i for i, x in enumerate(data.iloc[0]) if x == pos]
    nouns = [data.iloc[1][i] for i in indices if data.iloc[1][i] not in black_list]
    return bool(nouns)

# %%
start = time.time()
[x for x in range(1222222)]
end = time.time()
print(end - start)
start = time.time()
[x for x in range(12222222)]
end = time.time()
print(end - start)
# Out:
# 0.059784889221191406
# 0.5962908267974854

# %%
pd.set_option('display.max_rows', 40)

# %%
df_res = pd.DataFrame(columns=["text", "full_text", "rels", "poses", "lemmas"])
print_index = 1
for df_item in numpy_data:
    # clear_output(wait=True)
    res = df_item[df_raw.columns.get_indexer(["review_full_text"])[0]]
    doc = Doc(res)  # Doc(res.text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    doc.parse_syntax(syntax_parser)
    doc.tag_morph(morph_tagger)
    for token in doc.tokens:
        token.lemmatize(morph_vocab)
    data = doc.tokens
    columns = list(doc.tokens[0].as_json.keys())
    df_natasha = pd.DataFrame(data=data, columns=columns)
    df_objects = df_natasha[
        (df_natasha["rel"] == "root")
        | (df_natasha["rel"] == "conj")
        | (df_natasha["id"] == df_natasha["head_id"])
    ]
    temp = pd.DataFrame(
        df_objects.apply(lambda row: get_syntax(df_natasha, row), axis=1)
    )
    if temp.empty:
        continue
    temp[["text", "rels", "poses", "lemmas"]] = pd.DataFrame(
        list(temp[temp.columns[0]]), index=temp.index
    )
    temp = temp.drop([temp.columns[0]], axis=1)
    # result = temp[(temp["poses"].apply(lambda x: "NOUN" in x)) ]#& (temp["poses"].apply(lambda x: "ADJ" in x))]
    result = temp[
        (temp[["poses", "lemmas"]].apply(lambda x: isPos(x, "NOUN"), axis=1))
        & (temp[["poses", "lemmas"]].apply(lambda x: isPos(x, "ADJ"), axis=1))
    ]
    with pd.option_context('mode.chained_assignment', None):
        result["full_text"] = res
    df_res = pd.concat([df_res, result])

    display(fr"{ print_index } / { numpy_data.shape[0] }", clear=True)
    print_index += 1
df_res
# Out:
# '373 / 3288'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 22
#      15 df_natasha = pd.DataFrame(data=data, columns=columns)
#      16 df_objects = df_natasha[
#      17     (df_natasha["rel"] == "root")
#      18     | (df_natasha["rel"] == "conj")
#      19     | (df_natasha["id"] == df_natasha["head_id"])
#      20 ]
#      21 temp = pd.DataFrame(
# ---> 22     df_objects.apply(lambda row: get_syntax(df_natasha, row), axis=1)
#      23 )
#      24 if temp.empty:
#      25     continue
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\apply.py:831, in FrameApply.apply(self)
#     828 elif self.raw:
#     829     return self.apply_raw()
# --> 831 return self.apply_standard()
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\apply.py:957, in FrameApply.apply_standard(self)
#     956 def apply_standard(self):
# --> 957     results, res_index = self.apply_series_generator()
#     959     # wrap results
#     960     return self.wrap_results(results, res_index)
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\apply.py:973, in FrameApply.apply_series_generator(self)
#     970 with option_context("mode.chained_assignment", None):
#     971     for i, v in enumerate(series_gen):
#     972         # ignore SettingWithCopy here in case the user mutates
# --> 973         results[i] = self.func(v, *self.args, **self.kwargs)
#     974         if isinstance(results[i], ABCSeries):
#     975             # If we have a view on v, we need to make a copy because
#     976             #  series_generator will swap out the underlying data
#     977             results[i] = results[i].copy(deep=False)
#
# Cell In[79], line 22, in <lambda>(row)
#      15 df_natasha = pd.DataFrame(data=data, columns=columns)
#      16 df_objects = df_natasha[
#      17     (df_natasha["rel"] == "root")
#      18     | (df_natasha["rel"] == "conj")
#      19     | (df_natasha["id"] == df_natasha["head_id"])
#      20 ]
#      21 temp = pd.DataFrame(
# ---> 22     df_objects.apply(lambda row: get_syntax(df_natasha, row), axis=1)
#      23 )
#      24 if temp.empty:
#      25     continue
#
# Cell In[77], line 28, in get_syntax(df, row, text_cell)
#      25         res.append((row[text_cell], row["rel"], row["pos"], row["lemma"]))
#      26         isPrinted = True
# ---> 28 recursive(df,row, res, text_cell)
#      29 texts = [x[0] for x in res]
#      30 texts = re.sub(r'\s([?.!,;:"](?:\s|$))', r'\1', " ".join(texts))
#
# Cell In[77], line 5, in get_syntax.<locals>.recursive(df, row, res, text_cell)
#       4 def recursive(df, row, res, text_cell):
# ----> 5     edges = df[(df["head_id"]==row["id"])]
#       6     edges = edges[(edges["id"] != edges["head_id"])]
#       7     if edges.empty:
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\frame.py:3887, in DataFrame.__getitem__(self, key)
#    3885 # Do we have a (boolean) 1d indexer?
#    3886 if com.is_bool_indexer(key):
# -> 3887     return self._getitem_bool_array(key)
#    3889 # We are left with two options: a single key, and a collection of keys,
#    3890 # We interpret tuples as collections only for non-MultiIndex
#    3891 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\frame.py:3949, in DataFrame._getitem_bool_array(self, key)
#    3946     return self.copy(deep=None)
#    3948 indexer = key.nonzero()[0]
# -> 3949 return self._take_with_is_copy(indexer, axis=0)
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\generic.py:4088, in NDFrame._take_with_is_copy(self, indices, axis)
#    4077 @final
#    4078 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4079     """
#    4080     Internal version of the `take` method that sets the `_is_copy`
#    4081     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4086     See the docstring of `take` for full explanation of the parameters.
#    4087     """
# -> 4088     result = self.take(indices=indices, axis=axis)
#    4089     # Maybe set copy if we didn't actually change the index.
#    4090     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\internals\managers.py:877, in BaseBlockManager.take(self, indexer, axis, verify)
#     874 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     876 new_labels = self.axes[axis].take(indexer)
# --> 877 return self.reindex_indexer(
#     878     new_axis=new_labels,
#     879     indexer=indexer,
#     880     axis=axis,
#     881     allow_dups=True,
#     882     copy=None,
#     883 )
#
# File d:\Kirill\Desktop\Project\App\project\env\lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     685 if axis == 1:
#     686     # We can avoid the need to rebuild these
#     687     new_mgr._blknos = self.blknos.copy()
# --> 688     new_mgr._blklocs = self.blklocs.copy()
#     689 return new_mgr
#
# KeyboardInterrupt:

# %%
df = df_res.reset_index()
df = df.drop(["index"], axis=1)
df
# Out:
#                                                    text  \
# 0                                       Пластик прочный
# 1                                   есть съёмный поддон
# 2                                     идеальные размеры
# 3                                  красивый внешний вид
# 4                 Отдельное спасибо продавцу за подарок
# ...                                                 ...
# 4214               Лампа принципе не плохая десять дней
# 4215                   но сложно в с ДНаТ конкурировать
# 4216                     так и должно быть или это брак
# 4217                          измерил на следующей день
# 4218  На 50 в даже близко нет в сравнении с этой ест...
#
#                                               full_text  \
# 0     Взяла эти ящики для рассады и не пожалела.  Пл...
# 1     Взяла эти ящики для рассады и не пожалела.  Пл...
# 2     Взяла эти ящики для рассады и не пожалела.  Пл...
# 3     Взяла эти ящики для рассады и не пожалела.  Пл...
# 4     Взяла эти ящики для рассады и не пожалела.  Пл...
# ...                                                 ...
# 4214  Лампа в принципе не плохая,но с ДНаТ сложно ко...
# 4215  Лампа в принципе не плохая,но с ДНаТ сложно ко...
# 4216  Очень сильно греется, нагревается буквально за...
# 4217  заказывал на 200вт. измерил, показывала 80 вт,...
# 4218  На 50в даже близко нет,не замеряли, есть прост...
#
#                                                    rels  \
# 0                                         [nsubj, root]
# 1                                   [root, amod, nsubj]
# 2                                          [amod, conj]
# 3                                    [amod, amod, conj]
# 4                        [amod, root, iobj, case, nmod]
# ...                                                 ...
# 4214       [nsubj, obl, advmod, root, nummod:gov, iobj]
# 4215                 [cc, conj, case, case, obl, csubj]
# 4216         [cc, fixed, conj, xcomp, cc, nsubj, nsubj]
# 4217                            [root, case, amod, obl]
# 4218  [case, obl, case, advmod, advmod, advcl, case,...
#
#                                                   poses  \
# 0                                           [NOUN, ADJ]
# 1                                     [VERB, ADJ, NOUN]
# 2                                           [ADJ, NOUN]
# 3                                      [ADJ, ADJ, NOUN]
# 4                          [ADJ, NOUN, NOUN, ADP, NOUN]
# ...                                                 ...
# 4214                 [NOUN, NOUN, PART, ADJ, NUM, NOUN]
# 4215                 [CCONJ, ADJ, ADP, ADP, NOUN, VERB]
# 4216          [ADV, PART, ADJ, VERB, CCONJ, PRON, NOUN]
# 4217                             [VERB, ADP, ADJ, NOUN]
# 4218  [ADP, NUM, ADP, PART, ADV, VERB, ADP, NOUN, AD...
#
#                                                  lemmas
# 0                                    [пластик, прочный]
# 1                               [быть, съемный, поддон]
# 2                                   [идеальный, размер]
# 3                              [красивый, внешний, вид]
# 4           [отдельный, спасибо, продавец, за, подарок]
# ...                                                 ...
# 4214         [лампа, принцип, не, плохой, десять, день]
# 4215           [но, сложный, в, с, днат, конкурировать]
# 4216            [так, и, должный, быть, или, это, брак]
# 4217                    [измерить, на, следующий, день]
# 4218  [на, 50, в, даже, близко, нет, в, сравнение, с...
#
# [4219 rows x 5 columns]

# %%
df.reindex(df.text.str.len().sort_values(ascending=True).index)[2000:2100]
# Out:
#                                          text  \
# 2420    и без повреждений за быструю поставку
# 1147    Полный комплект все хорошего качества
# 2191    Очень красивое кашпо хорошего размера
# 1158    Стойка хорошая все детали в комплекте
# 2715    Родставку купила белую в подарок маме
# ...                                       ...
# 2635   Доставка быстрая целая без повреждений
# 2917   Отличная подставка я думала будет хуже
# 1292   самый верхний это почти уже косяк вб 😣
# 105   яркие пятна видимо но вид это не портит
# 3858  Достаточно яркая подсветка для растений
#
#                                               full_text  \
# 2420  Отличный, качественный флорариум! Упаковано вс...
# 1147  Отличный парник! Очень рекомендую! Лёгок в сбо...
# 2191  Очень красивое кашпо хорошего размера, то что ...
# 1158  Стойка хорошая, все детали в комплекте. Собрал...
# 2715  Большое спасибо за качественное и красивое изд...
# ...                                                 ...
# 2635  Доставка быстрая, упаковка целая без поврежден...
# 2917  Отличная подставка, я думала будет хуже. Крепк...
# 1292  Пришли почти целые , самый верхний отколот нем...
# 105   Хорошие ящики. Обычные. Упакованы в коробку, ц...
# 3858  Достаточно яркая и недорогая подсветка для рас...
#
#                                                    rels  \
# 2420             [advmod, case, conj, case, amod, nmod]
# 1147                   [amod, nsubj, nsubj, amod, conj]
# 2191                   [advmod, amod, root, amod, nmod]
# 1158              [nsubj, root, det, nsubj, case, nmod]
# 2715               [nsubj, root, obj, case, nmod, iobj]
# ...                                                 ...
# 2635                    [nsubj, amod, conj, case, nmod]
# 2917            [amod, nsubj, nsubj, advcl, cop, advcl]
# 1292  [amod, amod, nsubj, advmod, advmod, amod, root...
# 105   [amod, nsubj, advmod, cc, nsubj, nsubj, advmod...
# 3858                   [advmod, amod, conj, case, nmod]
#
#                                                 poses  \
# 2420               [CCONJ, ADP, NOUN, ADP, ADJ, NOUN]
# 1147                     [ADJ, NOUN, PRON, ADJ, NOUN]
# 2191                      [ADV, ADJ, NOUN, ADJ, NOUN]
# 1158                 [ADJ, ADJ, DET, NOUN, ADP, NOUN]
# 2715              [PROPN, VERB, ADJ, ADP, NOUN, NOUN]
# ...                                               ...
# 2635                      [NOUN, ADJ, ADJ, ADP, NOUN]
# 2917                [ADJ, NOUN, PRON, VERB, AUX, ADJ]
# 1292    [ADJ, ADJ, PRON, ADV, ADV, NOUN, NOUN, PUNCT]
# 105   [ADJ, NOUN, ADV, CCONJ, NOUN, PRON, PART, VERB]
# 3858                      [ADV, ADJ, NOUN, ADP, NOUN]
#
#                                                  lemmas
# 2420       [и, без, повреждение, за, быстрый, поставка]
# 1147        [полный, комплект, весь, хороший, качество]
# 2191          [очень, красивый, кашпо, хороший, размер]
# 1158       [стойка, хороший, весь, деталь, в, комплект]
# 2715       [родставка, купить, белый, в, подарок, мама]
# ...                                                 ...
# 2635       [доставка, быстрый, целый, без, повреждение]
# 2917       [отличный, подставка, я, думать, быть, хуже]
# 1292    [самый, верхний, это, почти, уже, косяк, вб, 😣]
# 105   [яркий, пятно, видимо, но, вид, это, не, портить]
# 3858      [достаточно, яркий, подсветка, для, растение]
#
# [100 rows x 5 columns]

# %%
df["raw"] = [list(zip(*l)) for l in list(zip(df.lemmas, df.poses, df.rels))]

# %%
tokenizer = RegexTokenizer()
dostoevsky_model = FastTextSocialNetworkModel(tokenizer=tokenizer)
def foo(df, colname):
    messages = df[colname]
    results = dostoevsky_model.predict(messages, k=5)
    df[f"sentiment_{colname}"] = [{f"{k}_{colname}": round(v, 2) for k, v in dct.items()} for dct in results]
    df = pd.concat([df, df[f"sentiment_{colname}"].apply(pd.Series)], axis=1)
    df = df.drop([f"sentiment_{colname}"], axis=1)
    return df
df = foo(df, "text")
df = foo(df, "full_text")
df
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_3184\3312146909.py:7: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   df = pd.concat([df, df[f"sentiment_{colname}"].apply(pd.Series)], axis=1)
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_3184\3312146909.py:7: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   df = pd.concat([df, df[f"sentiment_{colname}"].apply(pd.Series)], axis=1)
#                                                    text  \
# 0                                       Пластик прочный
# 1                                   есть съёмный поддон
# 2                                     идеальные размеры
# 3                                  красивый внешний вид
# 4                 Отдельное спасибо продавцу за подарок
# ...                                                 ...
# 4214               Лампа принципе не плохая десять дней
# 4215                   но сложно в с ДНаТ конкурировать
# 4216                     так и должно быть или это брак
# 4217                          измерил на следующей день
# 4218  На 50 в даже близко нет в сравнении с этой ест...
#
#                                               full_text  \
# 0     Взяла эти ящики для рассады и не пожалела.  Пл...
# 1     Взяла эти ящики для рассады и не пожалела.  Пл...
# 2     Взяла эти ящики для рассады и не пожалела.  Пл...
# 3     Взяла эти ящики для рассады и не пожалела.  Пл...
# 4     Взяла эти ящики для рассады и не пожалела.  Пл...
# ...                                                 ...
# 4214  Лампа в принципе не плохая,но с ДНаТ сложно ко...
# 4215  Лампа в принципе не плохая,но с ДНаТ сложно ко...
# 4216  Очень сильно греется, нагревается буквально за...
# 4217  заказывал на 200вт. измерил, показывала 80 вт,...
# 4218  На 50в даже близко нет,не замеряли, есть прост...
#
#                                                    rels  \
# 0                                         [nsubj, root]
# 1                                   [root, amod, nsubj]
# 2                                          [amod, conj]
# 3                                    [amod, amod, conj]
# 4                        [amod, root, iobj, case, nmod]
# ...                                                 ...
# 4214       [nsubj, obl, advmod, root, nummod:gov, iobj]
# 4215                 [cc, conj, case, case, obl, csubj]
# 4216         [cc, fixed, conj, xcomp, cc, nsubj, nsubj]
# 4217                            [root, case, amod, obl]
# 4218  [case, obl, case, advmod, advmod, advcl, case,...
#
#                                                   poses  \
# 0                                           [NOUN, ADJ]
# 1                                     [VERB, ADJ, NOUN]
# 2                                           [ADJ, NOUN]
# 3                                      [ADJ, ADJ, NOUN]
# 4                          [ADJ, NOUN, NOUN, ADP, NOUN]
# ...                                                 ...
# 4214                 [NOUN, NOUN, PART, ADJ, NUM, NOUN]
# 4215                 [CCONJ, ADJ, ADP, ADP, NOUN, VERB]
# 4216          [ADV, PART, ADJ, VERB, CCONJ, PRON, NOUN]
# 4217                             [VERB, ADP, ADJ, NOUN]
# 4218  [ADP, NUM, ADP, PART, ADV, VERB, ADP, NOUN, AD...
#
#                                                  lemmas  \
# 0                                    [пластик, прочный]
# 1                               [быть, съемный, поддон]
# 2                                   [идеальный, размер]
# 3                              [красивый, внешний, вид]
# 4           [отдельный, спасибо, продавец, за, подарок]
# ...                                                 ...
# 4214         [лампа, принцип, не, плохой, десять, день]
# 4215           [но, сложный, в, с, днат, конкурировать]
# 4216            [так, и, должный, быть, или, это, брак]
# 4217                    [измерить, на, следующий, день]
# 4218  [на, 50, в, даже, близко, нет, в, сравнение, с...
#
#                                                     raw  skip_text  \
# 0        [(пластик, NOUN, nsubj), (прочный, ADJ, root)]       0.09
# 1     [(быть, VERB, root), (съемный, ADJ, amod), (по...       0.03
# 2        [(идеальный, ADJ, amod), (размер, NOUN, conj)]       0.00
# 3     [(красивый, ADJ, amod), (внешний, ADJ, amod), ...       0.07
# 4     [(отдельный, ADJ, amod), (спасибо, NOUN, root)...       0.01
# ...                                                 ...        ...
# 4214  [(лампа, NOUN, nsubj), (принцип, NOUN, obl), (...       0.14
# 4215  [(но, CCONJ, cc), (сложный, ADJ, conj), (в, AD...       0.02
# 4216  [(так, ADV, cc), (и, PART, fixed), (должный, A...       0.00
# 4217  [(измерить, VERB, root), (на, ADP, case), (сле...       0.01
# 4218  [(на, ADP, case), (50, NUM, obl), (в, ADP, cas...       0.01
#
#       neutral_text  positive_text  negative_text  speech_text  \
# 0             0.09           0.02           0.02         0.00
# 1             0.89           0.01           0.01         0.00
# 2             0.99           0.01           0.09         0.00
# 3             0.73           0.31           0.00         0.00
# 4             0.13           0.01           0.00         0.73
# ...            ...            ...            ...          ...
# 4214          0.09           0.12           0.18         0.00
# 4215          0.85           0.00           0.08         0.00
# 4216          0.98           0.03           0.06         0.00
# 4217          0.97           0.03           0.07         0.00
# 4218          0.92           0.13           0.11         0.00
#
#       positive_full_text  neutral_full_text  skip_full_text  \
# 0                   0.21               0.14            0.10
# 1                   0.21               0.14            0.10
# 2                   0.21               0.14            0.10
# 3                   0.21               0.14            0.10
# 4                   0.21               0.14            0.10
# ...                  ...                ...             ...
# 4214                0.07               0.26            0.28
# 4215                0.07               0.26            0.28
# 4216                0.07               0.58            0.07
# 4217                0.10               0.82            0.07
# 4218                0.12               0.86            0.02
#
#       negative_full_text  speech_full_text
# 0                   0.08              0.04
# 1                   0.08              0.04
# 2                   0.08              0.04
# 3                   0.08              0.04
# 4                   0.08              0.04
# ...                  ...               ...
# 4214                0.32              0.01
# 4215                0.32              0.01
# 4216                0.17              0.00
# 4217                0.09              0.00
# 4218                0.10              0.00
#
# [4219 rows x 16 columns]

# %%
df.to_csv("./data/for_clustering.csv")

# %%
df_sub = df[(df["negative_full_text"] > 0.4) & (df["positive_full_text"] < 0.2)]
len(df_sub)
# Out:
# 169

# %%
nouns = pd.Series(
    [
        item[0]
        for sublist in df_sub["raw"]
        for item in sublist
        if not (item[0] in stopwords_ru or re.search(rf"\d|[{punctuation}]", item[0]))
        and item[1] == "NOUN"
    ]
).value_counts()
nouns
# Out:
# горшок        11
# ящик          10
# упаковка      10
# товар          9
# качество       5
#               ..
# балкон         1
# подарок        1
# щедрость       1
# склад          1
# чередовать     1
# Name: count, Length: 204, dtype: int64

# %%
df_nouns = df_sub
df_nouns["noun"] = df_nouns["raw"].apply(lambda x: 
    [
        item[0]
        for item in x
        if not (item[0] in stopwords_ru or re.search(rf"\d|[{punctuation}]", item[0]))
        and item[1] == "NOUN"
    ])
df_nouns = df_nouns.explode("noun")

df_x = df_nouns.groupby(["noun"])["text"].agg({
    ". ".join,
})
df_x.columns = [col[0] for col in df_x.columns]
# df_x[df_x.columns[0]].agg(len).sort_values(ascending=False)
df_nouns = pd.DataFrame(df_x[df_x.columns[0]])
df_nouns["len"] = df_nouns["j"].agg(len)
df_nouns = df_nouns.sort_values("len", ascending=False)
df_nouns
# Out:
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_3184\3080119999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nouns["noun"] = df_nouns["raw"].apply(lambda x:
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_3184\3080119999.py:17: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   df_nouns["len"] = df_nouns["j"].agg(len)
#                                                                                                                                                                                                                                                                                                                                                                                                                         j  \
# noun
# горшок    Сам горшок не плохой. Не тот цветочный горшок. а пришли снаружи чёрные в белом кашпо коричневые быть в Нутри как дор горшок. Горшки не плохие для рассады. Хорошие горшки не особо толстый но гибкий при аккуратном обращении хватит больше чем на сезон. Нормальные транспортировочные горшки. Но почему сломанному по одному горшку отправляют. невозможно Эти горшки закрыть когда насыпана земля. Я полч...
# товар     Сам товар был бы хорош если целый. я понимаю когда входе транспортировки ломается товар отломанные куски как это назвать что его таким Если положили находились бы. что везёте на пункт выдачи плохой товар. Товар не дорогой. Отвратительный товар ненадлежащего качества пришел разбитым. Заказала 2 шт одновременно Очень достойного качества Мало того что отправили разными посылками В остальном прете...
# упаковка  я не могу понять только одного в без дополнительной упаковки пупырчатой ленты отправлять пластмассовые изделия обычном целофане. очень обидно почему нет никакой упаковки. плохая упаковка. Плохая упаковка. Оригинальная упаковка лечуза вскрыта. пришел с треснутым стеклом когда уже выкинула все упаковки. Упаковка колышки торчали в разные стороны. Рваная упаковка. Упаковка просто ужасна Жесть. Упа...
# доставка  в дне там не трещина была все доставка так как принимала у курьера скорее не я😢 капец я понимаю через курьера сейчас напишете что вы что это виновата с потёртостями доставка Wildberries как можно. в дне там не трещина была все доставка так как принимала у курьера скорее не я😢 капец я понимаю через курьера сейчас напишете что вы что это виновата с потёртостями доставка Wildberries как можно. До...
# ящик      Ящики неплохие. Упаковано хорошо детали отколотой небыло значит на складе заведомо кладут разбитые ящики. но упакованы Ящики то хорошие просто в полиэтиленовую пленку из за чего верхний пришол колотый. Замечательные ящики. Один ящик оказался с отбитым краем. Заказала два белых ящика. В целый ящик запихнули разбитый. Ящики глубокие. Ящики вроде не плохие. Итог возврат платный ввязаться не охота...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# грызун                                                                                                                                                                                                                                                                                                                                                                                                    и погрыз грызун
# опора                                                                                                                                                                                                                                                                                                                                                                                                       Удобная опора
# мятый                                                                                                                                                                                                                                                                                                                                                                                                       Коробка мятая
# кривая                                                                                                                                                                                                                                                                                                                                                                                                       Косой кривой
# битый                                                                                                                                                                                                                                                                                                                                                                                                        Второй битый
#
#           len
# noun
# горшок    547
# товар     544
# упаковка  517
# доставка  442
# ящик      427
# ...       ...
# грызун     15
# опора      13
# мятый      13
# кривая     12
# битый      12
#
# [204 rows x 2 columns]

# %%
def get_counts(corpus):
    try:
        regex = re.compile(r"(\sне)\s", re.IGNORECASE)
        corpus = regex.sub(r"\g<1>", corpus)
        
        doc_corpus = Doc(corpus)
        doc_corpus.segment(segmenter)
        doc_corpus.tag_morph(morph_tagger)
        doc_corpus.parse_syntax(syntax_parser)
        doc_corpus.tag_morph(morph_tagger)
        for token in doc_corpus.tokens:
            token.lemmatize(morph_vocab)
        data_natasha = doc_corpus.tokens
        columns = list(doc_corpus.tokens[0].as_json.keys())
        df_natasha = pd.DataFrame(data=data_natasha, columns=columns)
        
        df_adj = df_natasha[df_natasha["pos"] == "ADJ"]
        if len(df_adj.index) == 0:
            return []
        
        cv = CountVectorizer()   
        cv_fit = cv.fit_transform(df_adj['lemma'])    
        word_list = cv.get_feature_names_out() 
        count_list = cv_fit.toarray().sum(axis=0)
        df_counts = pd.DataFrame.from_dict(zip(word_list,count_list))
        df_counts = df_counts.rename({0: 'token', 1: 'count'}, axis=1)
        df_counts = df_counts.sort_values(["count"], ascending=False)
        df_counts = df_counts[df_counts["count"] > 1]
        
        return df_counts.to_dict('tight')["data"]
    except:
        return []

# %%
pd.set_option('display.max_rows', 20)

# %%
noun_lemmas = df_nouns["j"].agg(get_counts)
df_noun_words_counts = pd.DataFrame(noun_lemmas)
df_noun_words_counts
# Out:
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_3184\2695223464.py:1: FutureWarning: using <function get_counts at 0x0000019C8F9ED670> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   noun_lemmas = df_nouns["j"].agg(get_counts)
#                                                     j
# noun
# горшок                                [[неплохой, 2]]
# товар                                              []
# упаковка                                [[плохой, 2]]
# доставка  [[виноватый, 2], [нея, 2], [потертость, 2]]
# ящик                                  [[неплохой, 2]]
# ...                                               ...
# грызун                                             []
# опора                                              []
# мятый                                              []
# кривая                                             []
# битый                                              []
#
# [204 rows x 1 columns]

# %%
pd.set_option('max_colwidth', 400)
pd.set_option('display.max_rows', 25)

# %%
df_noun_words_counts[df_noun_words_counts["j"].agg(len) > 0]
# Out:
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_3184\3500821967.py:1: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   df_noun_words_counts[df_noun_words_counts["j"].agg(len) > 0]
#                                                     j
# noun
# горшок                                [[неплохой, 2]]
# упаковка                                [[плохой, 2]]
# доставка  [[виноватый, 2], [нея, 2], [потертость, 2]]
# ящик                                  [[неплохой, 2]]
# курьер    [[виноватый, 2], [нея, 2], [потертость, 2]]
# черный                                  [[черный, 2]]
# лист               [[недержать, 2], [пластиковый, 2]]
# полка                  [[невставить, 2], [разный, 2]]
# интерьер                                [[черный, 2]]
# пластик                                 [[тонкий, 2]]
# отказ                                  [[платный, 2]]
