# %% [markdown]
# # Imports

# %%
import json
import math
import re
import time
from datetime import datetime
from string import punctuation, whitespace

import emoji
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
from natasha import (PER, Doc, MorphVocab, NamesExtractor, NewsEmbedding,
                     NewsMorphTagger, NewsNERTagger, NewsSyntaxParser,
                     Segmenter)
from nltk.corpus import stopwords
from selenium import webdriver

# %%
stopwords_ru = stopwords.words("russian")
segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

# %% [markdown]
# # Parsing

# %%
with open("./data/last_parsed_html.txt", "r+", encoding="UTF8") as f:
    html = "".join(f.readlines())
    soup = BeautifulSoup(html)

# %%
reviews = soup.findAll("li", class_="comments__item feedback j-feedback-slide")

# %%
res = []
for review in reviews:
    text = review.find("p", class_="feedback__text")
    title_element = review.find("span", class_=lambda value: value and value.startswith("feedback__rating stars-line"))
    res.append({"full_text": text.text, "rating": title_element["class"][-1][-1]})
soup.decompose()

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 10)
df = pd.DataFrame.from_dict(res)
df.head(10)
# Out:
#                                            full_text rating
# 0  Отличный горшок. Пришло всё целое. Спасибо за ...      5
# 1                                Качественный горшок      5
# 2  Удобные стильные горшки , покупаю не первый раз .      5
# 3  Классный горшок для цветов заказываю уже трети...      5
# 4  Спасибо,горшки красивые,но немного обидно,что ...      5
# 5  Все замечательно, хорошо упакован и очень прия...      5
# 6  Очень довольна горшками,индикатор работает отл...      5
# 7                  Горшок большой, все пришло целое!      5
# 8  Описание крайне не верное. Горшок напольный. О...      2
# 9                                              👍👍👍👍👍      5

# %%
df.describe()
# Out:
#              full_text rating
# count              698    698
# unique             687      5
# top     Хороший горшок      5
# freq                 5    547

# %%
df
# Out:
#                                              full_text rating
# 0    Отличный горшок. Пришло всё целое. Спасибо за ...      5
# 1                                  Качественный горшок      5
# 2    Удобные стильные горшки , покупаю не первый раз .      5
# 3    Классный горшок для цветов заказываю уже трети...      5
# 4    Спасибо,горшки красивые,но немного обидно,что ...      5
# ..                                                 ...    ...
# 693  Доброго дня! Вместо горшка на 9л. прислали на ...      5
# 694  Отличный горшок. Удобная система полива. Выгля...      5
# 695  Отличный горшок, теперь хочу собрать всю колле...      5
# 696  Хороший горшок, нужного мне размера. Правильна...      5
# 697  Очень понравился горшок, но с автополивом зака...      5
#
# [698 rows x 2 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Emoji

# %%
remove_list = list(emoji.EMOJI_DATA.keys()) + list("0123456789")

df["full_text"] = df["full_text"].map(
    lambda x: "".join(c for c in x if c not in remove_list)
)
# extract_emojis("👌💚все понравилось , закажу еще один")
df = df.drop(df[df["full_text"].map(lambda x: x == "")].index, axis=0)
df.head(10)
# Out:
#                                             full_text rating
# 0   Отличный горшок. Пришло всё целое. Спасибо за ...      5
# 1                                 Качественный горшок      5
# 2   Удобные стильные горшки , покупаю не первый раз .      5
# 3   Классный горшок для цветов заказываю уже трети...      5
# 4   Спасибо,горшки красивые,но немного обидно,что ...      5
# 5   Все замечательно, хорошо упакован и очень прия...      5
# 6   Очень довольна горшками,индикатор работает отл...      5
# 7                   Горшок большой, все пришло целое!      5
# 8   Описание крайне не верное. Горшок напольный. О...      2
# 10  Очень интересный горшочек. Удобная колба для к...      5

# %% [markdown]
# # Speller

# %%
df['full_text_Count'] = df['full_text'].str.len()
df['full_text_Count'].describe()
# Out:
# count    696.000000
# mean     112.466954
# std      118.909150
# min       10.000000
# 25%       38.750000
# 50%       78.000000
# 75%      140.250000
# max      980.000000
# Name: full_text_Count, dtype: float64

# %%
df.iloc[3]["full_text"]
df[df['full_text_Count'] >= df['full_text_Count'].describe()["75%"]]
# Out:
#                                              full_text rating  full_text_Count
# 3    Классный горшок для цветов заказываю уже трети...      5              220
# 8    Описание крайне не верное. Горшок напольный. О...      2              191
# 10   Очень интересный горшочек. Удобная колба для к...      5              244
# 11   Горшок очень симпатичный. На вид горшок большо...      5              377
# 12   Отличное кашпо!!! Всё в комплекте!!! Идеально ...      5              271
# ..                                                 ...    ...              ...
# 678  Во-первых горшок состоит из двух, когда брал д...      3              296
# 686  Горшочек очень понравился!!! К сезону отпусков...      5              171
# 691  Из трех горшков объёмом  литров,один был с диф...      5              220
# 695  Отличный горшок, теперь хочу собрать всю колле...      5              149
# 697  Очень понравился горшок, но с автополивом зака...      5              207
#
# [174 rows x 3 columns]

# %%
def speller_api(texts, df, first_index, last_index):
    payload = {'text': texts, 'options': 526} 
    try: 
        r = requests.post('https://speller.yandex.net/services/spellservice.json/checkTexts?', data=payload)
        r.encoding = 'utf-8'
        res = r.json()
        print(res)
        for i in range(len(texts)):
            df_i = i + first_index
            # Добавить число с которого начинается отсчет
            for mistake_ind in range(len(res[i])):
                suggestion = res[i][mistake_ind]
                if suggestion["s"]:
                    print(df.iloc[df_i]["full_text"])
                    df.iloc[df_i]["full_text"] = (
                        df["full_text"].iloc[df_i][: suggestion["pos"]]
                        + suggestion["s"][0]
                        + df["full_text"].iloc[df_i][suggestion["pos"] + suggestion["len"] :]
                    )
                    print(df.iloc[df_i]["full_text"])
    except Exception as e:
        print(e)
        print(r.text)

# %%
first_index = 0
max_sum = 10000
last_index = 0
for last_index, row in df.iterrows():
    if df.iloc[first_index:last_index]["full_text_Count"].sum() >= max_sum:
        texts = df.iloc[first_index:last_index]["full_text"]
        # print(df.iloc[first_index:last_index]["full_text_Count"].sum(), len(texts))
        speller_api(texts, df, first_index, last_index)
        first_index = last_index
texts = df.iloc[first_index:last_index + 1]["full_text"]
speller_api(texts, df, first_index, last_index)
# Out:
# [[], [], [], [], [], [{'code': 1, 'pos': 58, 'row': 0, 'col': 58, 'len': 11, 'word': 'обнаружил а', 's': ['обнаружила']}], [], [], [{'code': 1, 'pos': 16, 'row': 0, 'col': 16, 'len': 9, 'word': 'не верное', 's': ['неверное', 'не верное']}], [], [{'code': 1, 'pos': 71, 'row': 0, 'col': 71, 'len': 10, 'word': 'не большой', 's': ['небольшой']}, {'code': 1, 'pos': 199, 'row': 0, 'col': 199, 'len': 6, 'word': 'нечего', 's': ['ничего']}], [{'code': 1, 'pos': 140, 'row': 0, 'col': 140, 'len': 5, 'word': 'балов', 's': ['баллов']}, {'code': 1, 'pos': 236, 'row': 0, 'col': 236, 'len': 7, 'word': 'Вообщем', 's': ['в общем']}], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 120, 'row': 0, 'col': 120, 'len': 10, 'word': 'резерваура', 's': ['резервуара']}, {'code': 1, 'pos': 178, 'row': 0, 'col': 178, 'len': 10, 'word': 'на сколько', 's': ['насколько', 'на сколько']}], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 67, 'row': 0, 'col': 67, 'len': 7, 'word': 'пожесче', 's': ['пожестче']}, {'code': 1, 'pos': 85, 'row': 0, 'col': 85, 'len': 9, 'word': 'индиктора', 's': ['индикатора', 'индикатор']}, {'code': 1, 'pos': 497, 'row': 0, 'col': 497, 'len': 1, 'word': 'з', 's': ['за', 'з', 'зе']}], [], [], [], [], [], [], [{'code': 1, 'pos': 201, 'row': 0, 'col': 201, 'len': 10, 'word': 'продуманно', 's': ['продумано', 'продуманно']}], [], [], [{'code': 1, 'pos': 127, 'row': 1, 'col': 10, 'len': 12, 'word': 'заклееванием', 's': ['заклеиванием', 'заклещеванием']}], [], [{'code': 1, 'pos': 14, 'row': 0, 'col': 14, 'len': 9, 'word': 'запокован', 's': ['запакован', 'запакованный']}], [], [{'code': 1, 'pos': 37, 'row': 0, 'col': 37, 'len': 9, 'word': 'нравиться', 's': ['нравится', 'нравиться']}], [], [], [], [{'code': 1, 'pos': 27, 'row': 0, 'col': 27, 'len': 9, 'word': 'продавьцу', 's': ['продавцу', 'продавьцу']}], [], [], [], [{'code': 1, 'pos': 564, 'row': 0, 'col': 564, 'len': 6, 'word': 'эфекта', 's': ['эффекта']}], [], [], [], [], [], [{'code': 1, 'pos': 7, 'row': 0, 'col': 7, 'len': 10, 'word': 'семпотично', 's': ['симпатично', 'симпотично', 'симпатичной']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 252, 'row': 0, 'col': 252, 'len': 8, 'word': 'проверял', 's': ['проверил']}], [], [{'code': 1, 'pos': 55, 'row': 0, 'col': 55, 'len': 9, 'word': 'вприсался', 's': ['вписался', 'вписывался', 'выписался']}], [], [], [{'code': 1, 'pos': 288, 'row': 0, 'col': 288, 'len': 10, 'word': 'одоконнике', 's': ['подоконнике']}], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 0, 'row': 0, 'col': 0, 'len': 9, 'word': 'Клсассный', 's': ['Классный', 'Класный', 'Класссный']}], [], [], [], [], [], [], [], []]
# Все замечательно, хорошо упакован и очень приятно подарок обнаружил а внутри, спасибо
# Все замечательно, хорошо упакован и очень приятно подарок обнаружил а внутри, спасибо
# Описание крайне не верное. Горшок напольный. Объем самого горшка максимум - литров, остальное наружная оболочка. Планировали посадить высокий цветок, с большим корнем, этот горшок не подошёл.
# Описание крайне не верное. Горшок напольный. Объем самого горшка максимум - литров, остальное наружная оболочка. Планировали посадить высокий цветок, с большим корнем, этот горшок не подошёл.
# Горшок очень симпатичный. На вид горшок большой, по факту объем у него не большой. Пришло все целое, без каких-либо повреждений. Функция автополива у него хорошая. Посадила фикус, за  недели отпуска нечего не случилось с ним, жив-здоров. Не очень мне понятно как это работает, но земля влажная. Горшок отличный, рабочий, нужный. Хотелось бы и другие объёмы иметь дома. Спасибо.
# C:\Users\Kirill\AppData\Local\Temp\ipykernel_4856\1259591670.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[df_i]["full_text"] = (
# [[{'code': 1, 'pos': 77, 'row': 1, 'col': 7, 'len': 10, 'word': 'упакованый', 's': ['упакованный']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 13, 'row': 0, 'col': 13, 'len': 10, 'word': 'не большой', 's': ['небольшой', 'не большой']}], [{'code': 1, 'pos': 166, 'row': 0, 'col': 166, 'len': 9, 'word': 'Преобрела', 's': ['Приобрела']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 232, 'row': 0, 'col': 232, 'len': 12, 'word': 'самополивный', 's': ['самопаливный']}, {'code': 1, 'pos': 245, 'row': 0, 'col': 245, 'len': 7, 'word': 'горочек', 's': ['горшочек']}], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 296, 'row': 0, 'col': 296, 'len': 6, 'word': 'недели', 's': ['неделю', 'недели']}], [{'code': 1, 'pos': 122, 'row': 0, 'col': 122, 'len': 5, 'word': 'воцап', 's': ['вацап']}], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 151, 'row': 0, 'col': 151, 'len': 13, 'word': 'соотвественно', 's': ['соответственно']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 68, 'row': 0, 'col': 68, 'len': 6, 'word': 'незнаю', 's': ['не знаю']}, {'code': 1, 'pos': 79, 'row': 0, 'col': 79, 'len': 10, 'word': 'пересодить', 's': ['пересадить', 'пересодить']}], [], [], [], [], [{'code': 1, 'pos': 69, 'row': 1, 'col': 44, 'len': 9, 'word': 'вяснилось', 's': ['выяснилось']}], [{'code': 1, 'pos': 8, 'row': 0, 'col': 8, 'len': 9, 'word': 'царапайца', 's': ['царапается']}, {'code': 1, 'pos': 19, 'row': 0, 'col': 19, 'len': 2, 'word': 'но', 's': ['на', 'но', 'ну']}], [], [], [], [{'code': 1, 'pos': 91, 'row': 0, 'col': 91, 'len': 8, 'word': 'собраный', 's': ['собранный']}, {'code': 1, 'pos': 223, 'row': 0, 'col': 223, 'len': 2, 'word': 'но', 's': ['на']}], [], [], []]
# Хороший горшок, интерьерный. Все соответствует заявленному описанию.
# Пришёл упакованый в коробку и плёнку.
# Хороший горшок, интерьерный. Все соответствует заявленному описанию.
# Пришёл упакованый в коробку и плёнку.
# Горшок целый,не большой.Спасибо за подарок
# Горшок целый,не большой.Спасибо за подарок
# Хороший горшок. Пришёл хорошо упакованный, полный комплект, вложили подарочек. Но не забрала, стоимость на день получения упала на  руб.  Вот такая ценовая политика  Преобрела такой-же у другого продавца.
# Хороший горшок. Пришёл хорошо упакованный, полный комплект, вложили подарочек. Но не забрала, стоимость на день получения упала на  руб.  Вот такая ценовая политика  Преобрела такой-же у другого продавца.
# Очень странный горшок. Я так и не смогла разобраться в системе. Инструкция сильно скудная. Кашпо огромное, а самополивной горшочек с гулькин нос. В итоге я посадила дерево, для которого покупала этот горшок, в кашпо, а в хитроумный самополивный горочек посадила редис. Лью воду по инструкции, но она почти сразу заливает все. Не понравился система, к сожалению.
# Очень странный горшок. Я так и не смогла разобраться в системе. Инструкция сильно скудная. Кашпо огромное, а самополивной горшочек с гулькин нос. В итоге я посадила дерево, для которого покупала этот горшок, в кашпо, а в хитроумный самополивный горочек посадила редис. Лью воду по инструкции, но она почти сразу заливает все. Не понравился система, к сожалению.
# Купила -литровый, со вставкой  литров. Дома вяснилось, что во внутренней вставке еще одна вставка, которая уменьшает горшок еще на треть. Короче, матрёшка а не полноценный горшок.
# Никакого автополива нет и в помине. Просто внутри горшка постоянно стоит болото. Если посадить туда цветок боящийся сырости, он погибнет.
# Единственный плюс: кашпо смотрится неплохо. Но за такую цену, можно приобрести что-то более качественное и функциональное.
# Пластик царапайца, но горшок красивый
# Пластик царапайца, но горшок красивый
# Пластик царапайца, но горшок красивый
# Пластик царапайца, но горшок красивый
# Клевый горшочек, все работает. Собрал по инструкции. Он мелкий конечно, брал на , литра. В собраный горшок поместилось три бутылки воды по ,. Значит под корневую систему осталось меньше литра. Не знаю хорошо это или плохо) но горшок - топ) стоил бы дешевле- цены бы ему не было)
# Клевый горшочек, все работает. Собрал по инструкции. Он мелкий конечно, брал на , литра. В собраный горшок поместилось три бутылки воды по ,. Значит под корневую систему осталось меньше литра. Не знаю хорошо это или плохо) но горшок - топ) стоил бы дешевле- цены бы ему не было)
# Клевый горшочек, все работает. Собрал по инструкции. Он мелкий конечно, брал на , литра. В собраный горшок поместилось три бутылки воды по ,. Значит под корневую систему осталось меньше литра. Не знаю хорошо это или плохо) но горшок - топ) стоил бы дешевле- цены бы ему не было)
# Клевый горшочек, все работает. Собрал по инструкции. Он мелкий конечно, брал на , литра. В собраный горшок поместилось три бутылки воды по ,. Значит под корневую систему осталось меньше литра. Не знаю хорошо это или плохо) но горшок - топ) стоил бы дешевле- цены бы ему не было)
# [[], [], [], [], [], [], [], [], [{'code': 1, 'pos': 3, 'row': 0, 'col': 3, 'len': 7, 'word': 'угодала', 's': ['угадала', 'угодила']}], [], [], [{'code': 1, 'pos': 6, 'row': 0, 'col': 6, 'len': 9, 'word': 'перезаказ', 's': ['перезаказала', 'перезаказ', 'предзаказ', 'перезаказа', 'передзаказ']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 16, 'row': 0, 'col': 16, 'len': 3, 'word': 'доя', 's': ['для']}], [], [], [], [], [], [], [], [{'code': 1, 'pos': 25, 'row': 0, 'col': 25, 'len': 11, 'word': 'конс рукция', 's': ['конструкция']}, {'code': 1, 'pos': 108, 'row': 0, 'col': 108, 'len': 6, 'word': 'высотя', 's': ['высоты']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 19, 'row': 0, 'col': 19, 'len': 9, 'word': 'не плохой', 's': ['неплохой', 'на плохой']}, {'code': 1, 'pos': 71, 'row': 0, 'col': 71, 'len': 2, 'word': 'на', 's': ['не', 'но', 'на']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 73, 'row': 0, 'col': 73, 'len': 8, 'word': 'выпоняют', 's': ['выполняют', 'выполняет', 'выполнят']}], [], [], [], [], [], [], [], []]
# Не угодала маленький а так пойдёт
# Не угодала маленький а так пойдёт
# Брак, перезаказ.
# Брак, перезаказ.
# Отличный горшок доя фиалок все в комплекте, упакован надежно, спасибо!
# Отличный горшок доя фиалок все в комплекте, упакован надежно, спасибо!
# Треть по высоте занимает конс рукция дренажа/полива; общая высота горшка под корни на четверть мельче общей высотя горшка;
# Треть по высоте занимает конс рукция дренажа/полива; общая высота горшка под корни на четверть мельче общей высотя горшка;
# Треть по высоте занимает конс рукция дренажа/полива; общая высота горшка под корни на четверть мельче общей высотя горшка;
# Треть по высоте занимает конс рукция дренажа/полива; общая высота горшка под корни на четверть мельче общей высотя горшка;
# Сам по себе горшок не плохой. Но пришел с трещиной ((( Когда забирала, на заметила. Увидела только при сборке . Был упакован в коробку и пупырчатую пленку, значит это не вина доставки - таким его уже отправили .
# Сам по себе горшок не плохой. Но пришел с трещиной ((( Когда забирала, на заметила. Увидела только при сборке . Был упакован в коробку и пупырчатую пленку, значит это не вина доставки - таким его уже отправили .
# Сам по себе горшок не плохой. Но пришел с трещиной ((( Когда забирала, на заметила. Увидела только при сборке . Был упакован в коробку и пупырчатую пленку, значит это не вина доставки - таким его уже отправили .
# Сам по себе горшок не плохой. Но пришел с трещиной ((( Когда забирала, на заметила. Увидела только при сборке . Был упакован в коробку и пупырчатую пленку, значит это не вина доставки - таким его уже отправили .
# Добрый день! Хорошие горшки. Собирается все легко и просто. Свою функцию выпоняют. Был небольшой недочёт, продавец все быстро уладил. Спасибо!!!
# Добрый день! Хорошие горшки. Собирается все легко и просто. Свою функцию выпоняют. Был небольшой недочёт, продавец все быстро уладил. Спасибо!!!
# [[], [], [], [], [], [], [], [], [{'code': 1, 'pos': 419, 'row': 0, 'col': 419, 'len': 4, 'word': 'мирт', 's': ['мир', 'мэрт', 'мирт']}], [], [], [], [], [], [{'code': 1, 'pos': 112, 'row': 0, 'col': 112, 'len': 6, 'word': 'ни чем', 's': ['ничем']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 68, 'row': 0, 'col': 68, 'len': 10, 'word': 'не большой', 's': ['небольшой']}], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 29, 'row': 0, 'col': 29, 'len': 7, 'word': 'выглдит', 's': ['выглядит']}], [], [], [{'code': 1, 'pos': 32, 'row': 0, 'col': 32, 'len': 9, 'word': 'огромное️', 's': ['огромное', 'огромнное', 'огроммное', 'огрромное']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 111, 'row': 0, 'col': 111, 'len': 11, 'word': 'замечание.й', 's': ['замечание', 'замечаний', 'замечания.й']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 177, 'row': 0, 'col': 177, 'len': 10, 'word': 'равномерно', 's': ['равномерное']}], [], [], [], [], [], [{'code': 1, 'pos': 96, 'row': 0, 'col': 96, 'len': 2, 'word': 'тк', 's': ['т к', 'так']}], [], [], [], [], [], [{'code': 1, 'pos': 34, 'row': 0, 'col': 34, 'len': 12, 'word': 'использовния', 's': ['использования']}, {'code': 1, 'pos': 130, 'row': 0, 'col': 130, 'len': 11, 'word': 'удержаалась', 's': ['удержалась']}], [], [], [], [], [], []]
# Обман покупателя. Горшок литра. Можно подавать в суд!!! Белая часть, просто подставка, даже не кашпо! Между собой части не взаимодействуют! В серой нет отверстий. Она и так крохотная, да ещё подставка забирает место. Сравниваю с другой фирмой, где внешний контейнер, резервуар для воды. Здесь не так!!!  Огромное, никчёмное, непонятно что!!!   Только если у вас много места, посадить крохотное растение. Мой однолетний мирт не влез.
# Обман покупателя. Горшок литра. Можно подавать в суд!!! Белая часть, просто подставка, даже не кашпо! Между собой части не взаимодействуют! В серой нет отверстий. Она и так крохотная, да ещё подставка забирает место. Сравниваю с другой фирмой, где внешний контейнер, резервуар для воды. Здесь не так!!!  Огромное, никчёмное, непонятно что!!!   Только если у вас много места, посадить крохотное растение. Мой однолетний мирт не влез.
# [[], [], [{'code': 1, 'pos': 202, 'row': 1, 'col': 11, 'len': 13, 'word': 'перезаказ ать', 's': ['перезаказать', 'пересказать', 'перезаказть']}], [], [], [{'code': 1, 'pos': 33, 'row': 0, 'col': 33, 'len': 9, 'word': 'вписалось', 's': ['вписалась', 'вписались', 'вписалось']}], [], [], [], [], [], [], [{'code': 1, 'pos': 90, 'row': 0, 'col': 90, 'len': 6, 'word': 'недель', 's': ['недели']}], [{'code': 1, 'pos': 39, 'row': 0, 'col': 39, 'len': 10, 'word': 'не большой', 's': ['небольшой', 'не большой']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 25, 'row': 0, 'col': 25, 'len': 9, 'word': 'Посмотрии', 's': ['Посмотри', 'Посмотрим', 'Посмотрите']}], [], [], [], [], [], [], [{'code': 1, 'pos': 168, 'row': 0, 'col': 168, 'len': 17, 'word': 'не использованное', 's': ['неиспользованное', 'не использованное']}], [], [], [], [{'code': 1, 'pos': 0, 'row': 0, 'col': 0, 'len': 7, 'word': 'Пригелв', 's': ['Пришел в', 'Пришел', 'Пришёл в']}, {'code': 1, 'pos': 70, 'row': 0, 'col': 70, 'len': 4, 'word': 'тоде', 's': ['тоже', 'тоди']}], [], [], [], [], [], [], [], [{'code': 1, 'pos': 46, 'row': 0, 'col': 46, 'len': 7, 'word': 'пласмас', 's': ['пластмас', 'пласмас', 'пластмасс']}, {'code': 1, 'pos': 105, 'row': 0, 'col': 105, 'len': 7, 'word': 'вообщем', 's': ['в общем']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 110, 'row': 0, 'col': 110, 'len': 8, 'word': 'оттирала', 's': ['оттирал']}], [], [], [], [], [], [{'code': 1, 'pos': 84, 'row': 0, 'col': 84, 'len': 10, 'word': 'подарочек️', 's': ['подарочек', 'подарочки', 'подарочег']}], [], [], [], [], [], [], [], [{'code': 1, 'pos': 256, 'row': 0, 'col': 256, 'len': 6, 'word': 'незнаю', 's': ['не знаю']}], [], [], [], [], [{'code': 1, 'pos': 41, 'row': 0, 'col': 41, 'len': 7, 'word': 'падарок', 's': ['подарок']}, {'code': 1, 'pos': 58, 'row': 0, 'col': 58, 'len': 8, 'word': 'ударение', 's': ['удобрение', 'ударение']}], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 605, 'row': 0, 'col': 605, 'len': 4, 'word': 'Фото', 's': ['(Фото']}, {'code': 1, 'pos': 610, 'row': 0, 'col': 610, 'len': 6, 'word': 'так же', 's': ['также']}], [], [], []]
# Уважаемые, продавцы товар отличный, но опять возврат недоукомплектация, очень обидно, я его так ждала. Уже второй. Можно работать повнимательнее. Кашпо просто нет слов мои цветочки  радуются
# . Попробую перезаказ ать.
# Уважаемые, продавцы товар отличный, но опять возврат недоукомплектация, очень обидно, я его так ждала. Уже второй. Можно работать повнимательнее. Кашпо просто нет слов мои цветочки  радуются
# . Попробую перезаказ ать.
# Покупаю второй раз. Очень хорошо вписалось интерьер. Цветы пока не пересаживала, жду весну. Пока поставила в кашпо цветок в маленьком горшке.
# Покупаю второй раз. Очень хорошо вписалось интерьер. Цветы пока не пересаживала, жду весну. Пока поставила в кашпо цветок в маленьком горшке.
# Заявлен на л, а автополив всего на  литр, горшок качественный, без повреждений, но не на  недель без полива, максимум на неделю.  Более точную информацию надо предоставлять. Покупка была совершена с учетом информации о  неделях без полива. Я взяла его, так как есть кактусы дома, для них подойдёт, но не для цветов.
# [[], [], [], [], [{'code': 1, 'pos': 143, 'row': 1, 'col': 33, 'len': 8, 'word': 'горшоков', 's': ['горшков', 'горшочков']}], [], [{'code': 1, 'pos': 59, 'row': 0, 'col': 59, 'len': 6, 'word': 'лечузы', 's': ['лечуза']}], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 12, 'row': 0, 'col': 12, 'len': 2, 'word': 'тк', 's': ['т к', 'тк']}], [], [], [], [], [{'code': 1, 'pos': 118, 'row': 0, 'col': 118, 'len': 11, 'word': 'Спасибочкии', 's': ['Спасибочки', 'Спасибочки и', 'Спасибочкиии']}], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 26, 'row': 0, 'col': 26, 'len': 10, 'word': 'не большие', 's': ['небольшие', 'небольшые']}], [], [], [], [], [], [{'code': 1, 'pos': 0, 'row': 0, 'col': 0, 'len': 12, 'word': 'Cуперический', 's': ['Суперический']}, {'code': 1, 'pos': 44, 'row': 0, 'col': 44, 'len': 9, 'word': 'ответрсия', 's': ['отверстия', 'отверстие']}], [], [], [], [], [], [{'code': 1, 'pos': 8, 'row': 0, 'col': 8, 'len': 11, 'word': 'поцарапаный', 's': ['поцарапанный']}, {'code': 1, 'pos': 102, 'row': 0, 'col': 102, 'len': 6, 'word': 'корбке', 's': ['коробке']}], [], [], [], [{'code': 1, 'pos': 16, 'row': 0, 'col': 16, 'len': 7, 'word': 'В нутри', 's': ['Внутри']}], [], [], [], [], [], [], [{'code': 1, 'pos': 194, 'row': 0, 'col': 194, 'len': 10, 'word': 'не большой', 's': ['небольшой', 'небольшей']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 57, 'row': 0, 'col': 57, 'len': 8, 'word': 'спасибоо', 's': ['спасибо']}], [], [{'code': 1, 'pos': 40, 'row': 0, 'col': 40, 'len': 6, 'word': 'снятие', 's': ['снятия']}], [], [], [], [], [], [], []]
# Доставка в срок. Горшок пришел целый. Очень довольна товаром и хорошо, что не поверила отрицательным отзывам.
# Хотелось бы больший выбор объема горшоков.
# Доставка в срок. Горшок пришел целый. Очень довольна товаром и хорошо, что не поверила отрицательным отзывам.
# Хотелось бы больший выбор объема горшоков.
# Сильно понравился, прям достойный горшочек, у меня есть от лечузы, этот совсем ничем не уступает, тоже стильный  прочный. Довольна что привезли в коробочке, все целое было! возьму еще большой объем себе, дешевле и практичнее немцев
# Сильно понравился, прям достойный горшочек, у меня есть от лечузы, этот совсем ничем не уступает, тоже стильный  прочный. Довольна что привезли в коробочке, все целое было! возьму еще большой объем себе, дешевле и практичнее немцев
# Увы, отказ, тк пришёл разбитый.. Буду заказывать ещё.
# Увы, отказ, тк пришёл разбитый.. Буду заказывать ещё.
# восторгу нет предела, теперь я не забываю поливать цветы, они не чахнут, уже  месяца использования все супер классно! Спасибочкии))))
# восторгу нет предела, теперь я не забываю поливать цветы, они не чахнут, уже  месяца использования все супер классно! Спасибочкии))))
[], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 24, 'row': 0, 'col': 24, 'len': 8, 'word': 'палочки️', 's': ['палочки', 'палочкин', 'палочке', 'палочкой']}], [], [], [{'code': 1, 'pos': 18, 'row': 0, 'col': 18, 'len': 6, 'word': 'личузы', 's': ['лечузы', 'лидазы', 'линзы']}], [{'code': 1, 'pos': 63, 'row': 0, 'col': 63, 'len': 9, 'word': 'смоттрите', 's': ['смотрите']}, {'code': 1, 'pos': 82, 'row': 0, 'col': 82, 'len': 2, 'word': 'тк', 's': ['т к', 'тк', 'так']}], [], [], [{'code': 1, 'pos': 21, 'row': 0, 'col': 21, 'len': 5, 'word': 'Очннь', 's': ['Очень']}], [], [], [], [], [], [], [{'code': 1, 'pos': 64, 'row': 0, 'col': 64, 'len': 7, 'word': 'полива️', 's': ['полива']}], [], [], [], [], [{'code': 1, 'pos': 9, 'row': 0, 'col': 9, 'len': 5, 'word': 'кошпо', 's': ['кашпо', 'кошко']}], [], [{'code': 1, 'pos': 31, 'row': 0, 'col': 31, 'len': 8, 'word': 'горшоков', 's': ['горшков', 'горшоков', 'горшочков', 'горшаков']}, {'code': 1, 'pos': 40, 'row': 0, 'col': 40, 'len': 6, 'word': 'личуза', 's': ['лечуза', 'личуза']}], [{'code': 1, 'pos': 155, 'row': 0, 'col': 155, 'len': 6, 'word': 'горшек', 's': ['горшок']}, {'code': 1, 'pos': 371, 'row': 0, 'col': 371, 'len': 2, 'word': 'на', 's': ['но', 'на', 'не']}], [], [], [{'code': 1, 'pos': 33, 'row': 0, 'col': 33, 'len': 3, 'word': 'все', 's': ['всем']}], [], [{'code': 1, 'pos': 73, 'row': 0, 'col': 73, 'len': 11, 'word': 'Сероголубой', 's': ['Серо голубой', 'Серо голубое', 'Сероголубое']}], [], [], [], [], [], [{'code': 1, 'pos': 123, 'row': 0, 'col': 123, 'len': 8, 'word': 'вайбериз', 's': ['вайлдберриз']}], [{'code': 1, 'pos': 317, 'row': 0, 'col': 317, 'len': 9, 'word': 'не верные', 's': ['неверные']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 21, 'row': 0, 'col': 21, 'len': 9, 'word': 'меленьких', 's': ['маленьких', 'миленьких']}], [], []]
# Пришел целый и невредимый, упакован в коробочку. Спасибо за подарочек, мелочь, но приятно=))
# Пришел целый и невредимый, упакован в коробочку. Спасибо за подарочек, мелочь, но приятно=))
# Описание вынимаемого внутреннего горшка и автополива у кашпо  литр. не соответствует описанию, оно подходит для горшков мешьших обьемов! Там поплавок и трубки поступают именно так, как на ваших фото и вынув внутренний горшок вода останется в поддоне.В данном случае невозможно вынуть внутренний горшок и слить лишнюю воду, вода находится внутри него между дном и дренажной решеткой, количество воды невозможно узнать точно, тк не понятно она на дне или выше этой решётки.Таким образом, если перелить воду, можно загубить растение замочив корневую систему, тк циркуляции воздуха там не будет. Поэтому функциональность в данном случае автополива только мешает (л.). Получается что чтобы слить воду нужно будет перевернуть весь горшок с цветком и землёй, а это, как вы понимаете, не нормально . Если вы выложите видеоопровержение и докажите нам, что мы ошибаемся, будет очень неплохо. Так же вы можете признать то, что в этом варианте вы выполнили комплектацию неверно.
# Кашпо так кашпо! Большой горшок, идеален для пола. Внимательно смоттрите размеры, тк на стол не поставишь, большой сильно. А так очень красивый. Взяла  размера, еще  л. Дополню отзыв фото с двумя горшками, как получу второй.
# Горшок просто бомба! Очннь красивый, доставили быстро все было цело и упаковано в коробку ничего не повредилось!
# Горшок просто бомба! Очннь красивый, доставили быстро все было цело и упаковано в коробку ничего не повредилось!
# Хороший горшок, большой, автополив работает, на фото неделя без полива️
# Хороший горшок, большой, автополив работает, на фото неделя без полива️
# Отличное кошпо
# Отличное кошпо
# Крутой горшок. Выгодный аналог горшоков личуза и дешевле в  раз.
# Не вижу смысла переплачивать)))))))))))))))
# Крутой горшок. Выгодный аналог горшоков личуза и дешевле в  раз.
# Не вижу смысла переплачивать)))))))))))))))
# Крутой горшок. Выгодный аналог горшоков личуза и дешевле в  раз.
# Не вижу смысла переплачивать)))))))))))))))
# Крутой горшок. Выгодный аналог горшоков личуза и дешевле в  раз.
# Не вижу смысла переплачивать)))))))))))))))
# Пришел с одним отломанным ребром (фото). Менять не стал т.к. влом ждать. При приёме увидел, что размер горшка меньше части куда он вставляется, из за чего горшек проваливается во внутрь. После сборки так и оказалось.(фото). Как бы вы не заморачивались, он всегда проваливается. Может брак, может кривизна конструкции по факту, мне в целом без разницы. По итогу - задумка на  реализация на . К покупке не рекомендую.
# Пришел с одним отломанным ребром (фото). Менять не стал т.к. влом ждать. При приёме увидел, что размер горшка меньше части куда он вставляется, из за чего горшек проваливается во внутрь. После сборки так и оказалось.(фото). Как бы вы не заморачивались, он всегда проваливается. Может брак, может кривизна конструкции по факту, мне в целом без разницы. По итогу - задумка на  реализация на . К покупке не рекомендую.
# Пришел с одним отломанным ребром (фото). Менять не стал т.к. влом ждать. При приёме увидел, что размер горшка меньше части куда он вставляется, из за чего горшек проваливается во внутрь. После сборки так и оказалось.(фото). Как бы вы не заморачивались, он всегда проваливается. Может брак, может кривизна конструкции по факту, мне в целом без разницы. По итогу - задумка на  реализация на . К покупке не рекомендую.
# Пришел с одним отломанным ребром (фото). Менять не стал т.к. влом ждать. При приёме увидел, что размер горшка меньше части куда он вставляется, из за чего горшек проваливается во внутрь. После сборки так и оказалось.(фото). Как бы вы не заморачивались, он всегда проваливается. Может брак, может кривизна конструкции по факту, мне в целом без разницы. По итогу - задумка на  реализация на . К покупке не рекомендую.
# Понравился. Рекомендую к покупке все любителям стильных и удобных кашпо. Автополив - бомба
# Понравился. Рекомендую к покупке все любителям стильных и удобных кашпо. Автополив - бомба
# Зачем писать цвет изделия, который совершенно не совпадает с реальным... Сероголубой....
# Зачем писать цвет изделия, который совершенно не совпадает с реальным... Сероголубой....
# Полный комплект пришел, все трубочки-палочки есть, собирается легко. В комплекте инструкция, позже заметила что и на сайте вайбериз есть видео инструкция по сборке, что очень удобно. Горшок красивый и стильный, спасибо!
# Полный комплект пришел, все трубочки-палочки есть, собирается легко. В комплекте инструкция, позже заметила что и на сайте вайбериз есть видео инструкция по сборке, что очень удобно. Горшок красивый и стильный, спасибо!
# аккуратный горшок, но очень маленький. А вот цена за пластмассу наоборот. Большими буквами написано, что объем ,л. Считаю это введением в заблуждение покупателя, т.к. цветок сажается не во внешний горшок объемом ,л, а во внутренний вкладыш. А вот внутренний горшок, наверное / от внешнего))) И потом, продавец указал не верные  размеры горшка, на которые покупатель смотрит. Короче из-за недостоверной информации продавца о товаре была вынуждена отказаться при получении. Расстроена
# аккуратный горшок, но очень маленький. А вот цена за пластмассу наоборот. Большими буквами написано, что объем ,л. Считаю это введением в заблуждение покупателя, т.к. цветок сажается не во внешний горшок объемом ,л, а во внутренний вкладыш. А вот внутренний горшок, наверное / от внешнего))) И потом, продавец указал не верные  размеры горшка, на которые покупатель смотрит. Короче из-за недостоверной информации продавца о товаре была вынуждена отказаться при получении. Расстроена
# Классный горшок. Для меленьких растений. Упакован в коробку с инструкцией. Доставлен без повреждений.
# Классный горшок. Для меленьких растений. Упакован в коробку с инструкцией. Доставлен без повреждений.
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 22, 'row': 0, 'col': 22, 'len': 4, 'word': 'свой', 's': ['своей', 'свей']}], [], [], [], [], [], [{'code': 1, 'pos': 26, 'row': 0, 'col': 26, 'len': 7, 'word': 'Почитал', 's': ['Прочитал']}, {'code': 1, 'pos': 41, 'row': 0, 'col': 41, 'len': 6, 'word': 'предже', 's': ['прежде']}], [], [], [], [], [], [], [{'code': 1, 'pos': 11, 'row': 0, 'col': 11, 'len': 16, 'word': 'нефункциональный', 's': ['не функциональный', 'не функциональны']}], [], [{'code': 1, 'pos': 42, 'row': 0, 'col': 42, 'len': 8, 'word': 'сдержано', 's': ['сдержанно', 'сдержано']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# Прекрасный горшок. Со свой функцией справляется, на - недели воды хватает. Цветы довольны.
# Прекрасный горшок. Со свой функцией справляется, на - недели воды хватает. Цветы довольны.
# Горшок гут, всё работает. Почитал отзывы предже, чем заказывать, и знал, что маловат по объёму. Мне пока подходит средний, но, было бы лучше, если бы был больше.
# Горшок гут, всё работает. Почитал отзывы предже, чем заказывать, и знал, что маловат по объёму. Мне пока подходит средний, но, было бы лучше, если бы был больше.
# Горшок гут, всё работает. Почитал отзывы предже, чем заказывать, и знал, что маловат по объёму. Мне пока подходит средний, но, было бы лучше, если бы был больше.
# Горшок гут, всё работает. Почитал отзывы предже, чем заказывать, и знал, что маловат по объёму. Мне пока подходит средний, но, было бы лучше, если бы был больше.
# Годный) но нефункциональный.
# Годный) но нефункциональный.
# средний размер. Собрал легко . Смотрится  сдержано
# средний размер. Собрал легко . Смотрится  сдержано

# %%
payload = {'text': df["full_text"], 'options': 526} 
try: 
    # Максимум 10000 символов за раз. Обработки для этого нет, её, по хорошему, надо сделать
    r = requests.post('https://speller.yandex.net/services/spellservice.json/checkTexts?', data=payload)
    r.encoding = 'utf-8'
    res = r.json()
    print(res)
except Exception as e:
    print(e)
    print(r.text)
# Out:
# [[], [], [], [], [], [{'code': 1, 'pos': 58, 'row': 0, 'col': 58, 'len': 11, 'word': 'обнаружил а', 's': ['обнаружила']}], [], [], [{'code': 1, 'pos': 16, 'row': 0, 'col': 16, 'len': 9, 'word': 'не верное', 's': ['неверное', 'не верное']}], [], [{'code': 1, 'pos': 71, 'row': 0, 'col': 71, 'len': 10, 'word': 'не большой', 's': ['небольшой']}, {'code': 1, 'pos': 199, 'row': 0, 'col': 199, 'len': 6, 'word': 'нечего', 's': ['ничего']}], [{'code': 1, 'pos': 140, 'row': 0, 'col': 140, 'len': 5, 'word': 'балов', 's': ['баллов']}, {'code': 1, 'pos': 236, 'row': 0, 'col': 236, 'len': 7, 'word': 'Вообщем', 's': ['в общем']}], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 120, 'row': 0, 'col': 120, 'len': 10, 'word': 'резерваура', 's': ['резервуара']}, {'code': 1, 'pos': 178, 'row': 0, 'col': 178, 'len': 10, 'word': 'на сколько', 's': ['насколько', 'на сколько']}], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 67, 'row': 0, 'col': 67, 'len': 7, 'word': 'пожесче', 's': ['пожестче']}, {'code': 1, 'pos': 85, 'row': 0, 'col': 85, 'len': 9, 'word': 'индиктора', 's': ['индикатора', 'индикатор']}, {'code': 1, 'pos': 497, 'row': 0, 'col': 497, 'len': 1, 'word': 'з', 's': ['за', 'з', 'зе']}], [], [], [], [], [], [], [{'code': 1, 'pos': 201, 'row': 0, 'col': 201, 'len': 10, 'word': 'продуманно', 's': ['продумано', 'продуманно']}], [], [], [{'code': 1, 'pos': 127, 'row': 1, 'col': 10, 'len': 12, 'word': 'заклееванием', 's': ['заклеиванием', 'заклещеванием']}], [], [{'code': 1, 'pos': 14, 'row': 0, 'col': 14, 'len': 9, 'word': 'запокован', 's': ['запакован', 'запакованный']}], [], [{'code': 1, 'pos': 37, 'row': 0, 'col': 37, 'len': 9, 'word': 'нравиться', 's': ['нравится', 'нравиться']}], [], [], [], [{'code': 1, 'pos': 27, 'row': 0, 'col': 27, 'len': 9, 'word': 'продавьцу', 's': ['продавцу', 'продавьцу']}], [], [], [], [{'code': 1, 'pos': 564, 'row': 0, 'col': 564, 'len': 6, 'word': 'эфекта', 's': ['эффекта']}], [], [], [], [], [], [{'code': 1, 'pos': 7, 'row': 0, 'col': 7, 'len': 10, 'word': 'семпотично', 's': ['симпатично', 'симпотично', 'симпатичной']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 252, 'row': 0, 'col': 252, 'len': 8, 'word': 'проверял', 's': ['проверил']}], [], [{'code': 1, 'pos': 55, 'row': 0, 'col': 55, 'len': 9, 'word': 'вприсался', 's': ['вписался', 'вписывался', 'выписался']}], [], [], [{'code': 1, 'pos': 288, 'row': 0, 'col': 288, 'len': 10, 'word': 'одоконнике', 's': ['подоконнике']}], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 0, 'row': 0, 'col': 0, 'len': 9, 'word': 'Клсассный', 's': ['Классный', 'Класный', 'Класссный']}], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 77, 'row': 1, 'col': 7, 'len': 10, 'word': 'упакованый', 's': ['упакованный']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 13, 'row': 0, 'col': 13, 'len': 10, 'word': 'не большой', 's': ['небольшой', 'не большой']}], [{'code': 1, 'pos': 166, 'row': 0, 'col': 166, 'len': 9, 'word': 'Преобрела', 's': ['Приобрела']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 232, 'row': 0, 'col': 232, 'len': 12, 'word': 'самополивный', 's': ['самопаливный']}, {'code': 1, 'pos': 245, 'row': 0, 'col': 245, 'len': 7, 'word': 'горочек', 's': ['горшочек']}], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 296, 'row': 0, 'col': 296, 'len': 6, 'word': 'недели', 's': ['неделю', 'недели']}], [{'code': 1, 'pos': 122, 'row': 0, 'col': 122, 'len': 5, 'word': 'воцап', 's': ['вацап']}], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 151, 'row': 0, 'col': 151, 'len': 13, 'word': 'соотвественно', 's': ['соответственно']}], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [{'code': 1, 'pos': 68, 'row': 0, 'col': 68, 'len': 6, 'word': 'незнаю', 's': ['не знаю']}, {'code': 1, 'pos': 79, 'row': 0, 'col': 79, 'len': 10, 'word': 'пересодить', 's': ['пересадить', 'пересодить']}], [] ...

# %%
# Не копируется датафрейм, точнее не вставляются значения в "копию"
# df.iloc[0, "full_text"] = "123"
for i in range(len(df["full_text"])):
    for mistake_ind in range(len(res[i])):
        suggestion = res[i][mistake_ind]
        if suggestion["s"]:
            df.iloc[i, 'full_text'] = (
                df["full_text"].iloc[i][: suggestion["pos"]]
                + suggestion["s"][0]
                + df["full_text"].iloc[i][suggestion["pos"] + suggestion["len"] :]
            )

df

# %%
df.iloc[50]
# Out:
# full_text          Ребят, вы так и пишите, что горшок  л, а не . ...
# rating                                                             1
# full_text_Count                                                  108
# Name: 51, dtype: object

# %% [markdown]
# # Natasha

# %%
def get_syntax(df, row, text_cell = "text"):
    res = []
    
    def recursive(df, row, res, text_cell):
        edges = df[df["head_id"]==row["id"]]
        if edges.empty:
            if re.search(fr"[{punctuation}]", row[text_cell]):
                return
            res.append(row[text_cell])
            return
        
        isPrinted = False
        for index, edge in edges.iterrows():
            if edge["text"] == "(":
                k = 0
            if edge["rel"] == "conj":
                continue
            if text_cell == "lemma":
                if edge["text"] in stopwords_ru or re.search(fr"\d|[{punctuation}]", edge["text"]):
                    continue
            if int(edge["id"].split("_")[1]) > int(row["id"].split("_")[1]) and not isPrinted:
                res.append(row[text_cell])
                isPrinted = True
            recursive(df, edge, res, text_cell)
        if not isPrinted:
            res.append(row[text_cell])
            isPrinted = True
    
    recursive(df,row, res, text_cell)
    if text_cell == "text":
        res = re.sub(r'\s([?.!,;:"](?:\s|$))', r'\1', " ".join(res))
    return res

# %%
pd.set_option('display.max_rows', 10)

# %%
resarr = []
# try:
for df_item in df.to_numpy():
    res = df_item[df.columns.get_indexer(["text"])[0]]
    # res = df_item[0]
    doc = Doc(res)  # Doc(res.text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    doc.parse_syntax(syntax_parser)
    doc.tag_morph(morph_tagger)
    for token in doc.tokens:
        token.lemmatize(morph_vocab)
    data = doc.tokens
    columns = list(doc.tokens[0].as_json.keys())
    df_natasha = pd.DataFrame(data=data, columns=columns)

    df_natasha2 = df_natasha[
        (df_natasha["rel"] == "root") | (df_natasha["rel"] == "conj")
    ]
    # print(df_natasha)
    # print(df_natasha2)
    if df_natasha2.empty:
        df_natasha2 = df_natasha[df_natasha["id"] == df_natasha["head_id"]]
        if df_natasha2.empty:
            # print(df_natasha)
            # Если наташа не смогла определить подлежащее, то обычно отзыв бессмысленен
            continue
        df_natasha.loc[df_natasha2.index, ["head_id"]] = df_natasha2["head_id"].replace(
            to_replace=r"^(\d+_)(\d+)$", value=r"\g<1>" + "0", regex=True
        )
        df_natasha2 = df_natasha.loc[df_natasha2.index]
        # print(df_natasha2)
        df_natasha["syntax"] = df_natasha2.apply(
            lambda row: get_syntax(df_natasha, row), axis=1
        )
        df_natasha["syntax_lemmas"] = df_natasha2.apply(
            lambda row: get_syntax(df_natasha, row, text_cell="lemma"), axis=1
        )
        # print(df_natasha)
        df_natasha2 = df_natasha.loc[df_natasha2.index]
    else:
        df_natasha["syntax"] = df_natasha2.apply(
            lambda row: get_syntax(df_natasha, row), axis=1
        )
        df_natasha["syntax_lemmas"] = df_natasha2.apply(
            lambda row: get_syntax(df_natasha, row, text_cell="lemma"), axis=1
        )
        df_natasha2 = df_natasha[
            (df_natasha["rel"] == "root") | (df_natasha["rel"] == "conj")
        ]

    texts = df_natasha2["syntax"].values
    lemmas = df_natasha2["syntax_lemmas"].values
    for i in range(len(texts)):
        if len(texts[i]) < 2 or len(lemmas[i]) == 0:
            continue
        resarr.append(
            {
                "text": texts[i][0].upper() + texts[i][1:],
                "full_text": res,
                "class": 0,
                "lemmas": lemmas[i],
                "rating": df_item[1],
            }
        )
# except Exception as e:
#     print(e)
df_res = pd.DataFrame(resarr)
df_res
# Out:
#                                                    text  \
# 0                                       Отличный горшок
# 1                                      Пришло всё целое
# 2                        Спасибо за подарочек-удобрение
# 3                                   Качественный горшок
# 4         Удобные стильные горшки покупаю не первый раз
# ...                                                 ...
# 2602             Но с автополивом заказала первый раз а
# 2603  Поэтому не учла литров что внутренний на где т...
# 2604                          Это объём внешнего горшка
# 2605                                              Литра
# 2606                     Буду перезаказывать на больший
#
#                                               full_text  class  \
# 0     Отличный горшок. Пришло всё целое. Спасибо за ...      0
# 1     Отличный горшок. Пришло всё целое. Спасибо за ...      0
# 2     Отличный горшок. Пришло всё целое. Спасибо за ...      0
# 3                                   Качественный горшок      0
# 4     Удобные стильные горшки , покупаю не первый раз .      0
# ...                                                 ...    ...
# 2602  Очень понравился горшок, но с автополивом зака...      0
# 2603  Очень понравился горшок, но с автополивом зака...      0
# 2604  Очень понравился горшок, но с автополивом зака...      0
# 2605  Очень понравился горшок, но с автополивом зака...      0
# 2606  Очень понравился горшок, но с автополивом зака...      0
#
#                                                  lemmas rating
# 0                                    [отличный, горшок]      5
# 1                                 [прийти, весь, целый]      5
# 2                                             [спасибо]      5
# 3                                [качественный, горшок]      5
# 4                 [удобный, стильный, горшок, покупать]      5
# ...                                                 ...    ...
# 2602                              [автополив, заказать]      5
# 2603  [поэтому, учесть, литр, внутренний, это, мален...      5
# 2604                      [это, объем, внешний, горшок]      5
# 2605                                             [литр]      5
# 2606                    [быть, перезаказывать, больший]      5
#
# [2607 rows x 5 columns]

# %% [markdown]
# # Save

# %%
dt = datetime.utcnow().strftime('%Y-%m-%d-%H-%M-%S')
file_path = f"./data/unprepared_{dt}.xlsx"
df_res.to_excel(file_path, encoding="UTF-8")
