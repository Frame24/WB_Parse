# %%
df_raw.head()
# Out:
#    Unnamed: 0                                   review_full_text  \
# 0           0                                   Работает хорошо.
# 1           1  Пришло быстро, все целое на вид. Завтра буду и...
# 2           2  Купил на квадр для поднятия отвала, установка ...
# 3           3  Лебёдка хорошая. Но в инструкции ни слова про ...
# 4           4  Всё в комплекте, есть инструкция на русском яз...
#
#    review_rating                                            product  \
# 0              5  Shtapler / Лебедка электрическая 12v 3000lb 13...
# 1              5  Shtapler / Лебедка электрическая 12v 3000lb 13...
# 2              5  Shtapler / Лебедка электрическая 12v 3000lb 13...
# 3              5  Shtapler / Лебедка электрическая 12v 3000lb 13...
# 4              5  Shtapler / Лебедка электрическая 12v 3000lb 13...
#
#               category                                                url
# 0  /Автотовары/OFFroad  https://www.wildberries.ru/catalog/162315454/f...
# 1  /Автотовары/OFFroad  https://www.wildberries.ru/catalog/162315454/f...
# 2  /Автотовары/OFFroad  https://www.wildberries.ru/catalog/162315454/f...
# 3  /Автотовары/OFFroad  https://www.wildberries.ru/catalog/162315454/f...
# 4  /Автотовары/OFFroad  https://www.wildberries.ru/catalog/162315454/f...

# %%
import pandas as pd
import json

# Функция для загрузки данных из JSON-файла и преобразования их в DataFrame
def load_json_to_df(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
        
    df = pd.DataFrame(columns=['Category', 'Subcategory', 'Characteristic', 'Synonyms', 'Units'])
    
    for category in data['categories']:
        category_name = category['category_name']
        
        for subcategory in category['subcategories']:
            subcategory_name = subcategory['subcategory_name']
            
            for characteristic in subcategory['characteristics']:
                characteristic_name = characteristic['name']
                synonyms = ', '.join(characteristic['synonyms'])  # Объединение синонимов в строку
                units = ', '.join(characteristic['units'])  # Объединение единиц измерения в строку
                
                # Добавление строки в DataFrame
                df = df.append({
                    'Category': category_name,
                    'Subcategory': subcategory_name,
                    'Characteristic': characteristic_name,
                    'Synonyms': synonyms,
                    'Units': units
                }, ignore_index=True)
    
    return df

# Загрузка данных из обоих файлов
df1 = load_json_to_df('./reviews_keywords/categories.json')
df2 = load_json_to_df('./reviews_keywords/categories2.json')

# Объединение двух DataFrame
combined_df = pd.concat([df1, df2], ignore_index=True)

# Вывод результата
print(combined_df.head())  # Показать первые 5 строк объединенного DataFrame

# Сохранение объединенного DataFrame в CSV файл, если необходимо
combined_df.to_csv('./reviews_keywords/combined_categories_dataframe.csv', index=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# ...
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
#                 Category Subcategory      Characteristic  \
# 0  Электроника и гаджеты   Смартфоны               Экран
# 1  Электроника и гаджеты   Смартфоны             Батарея
# 2  Электроника и гаджеты   Смартфоны              Камера
# 3  Электроника и гаджеты   Смартфоны           Процессор
# 4  Электроника и гаджеты   Смартфоны  Оперативная память
#
#                                     Synonyms               Units
# 0          дисплей, экранная панель, матрица  дюймы, см, пиксели
# 1    аккумулятор, батарейка, емкость батареи                мА·ч
# 2  фотокамера, объектив, камера заднего вида      Мп, разрешение
# 3                чип, CPU, процессорное ядро           ГГц, ядра
# 4                    RAM, оперативка, память                  ГБ
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return fn(*args, **kwargs)

# %%
combined_df
# Out:
#                   Category           Subcategory      Characteristic  \
# 0    Электроника и гаджеты             Смартфоны               Экран
# 1    Электроника и гаджеты             Смартфоны             Батарея
# 2    Электроника и гаджеты             Смартфоны              Камера
# 3    Электроника и гаджеты             Смартфоны           Процессор
# 4    Электроника и гаджеты             Смартфоны  Оперативная память
# ..                     ...                   ...                 ...
# 608       Электротранспорт  Общие характеристики                Цена
# 609       Электротранспорт  Общие характеристики            Качество
# 610       Электротранспорт  Общие характеристики       Производитель
# 611       Электротранспорт  Общие характеристики            Гарантия
# 612       Электротранспорт  Общие характеристики                 Вес
#
#                                         Synonyms                 Units
# 0              дисплей, экранная панель, матрица    дюймы, см, пиксели
# 1        аккумулятор, батарейка, емкость батареи                  мА·ч
# 2      фотокамера, объектив, камера заднего вида        Мп, разрешение
# 3                    чип, CPU, процессорное ядро             ГГц, ядра
# 4                        RAM, оперативка, память                    ГБ
# ..                                           ...                   ...
# 608           стоимость, ценник, цена за единицу  рубли, доллары, евро
# 609     сборка, материалы, качество изготовления
# 610                       бренд, компания, марка
# 611  гарантийный срок, гарантийные обязательства          годы, месяцы
# 612                        масса, вес устройства                    кг
#
# [613 rows x 5 columns]

# %%
import os
import gdown

def download_file_if_not_exists(file_url, output_path):
    """Скачивает файл с Google Drive, если он ещё не существует в указанной директории."""
    # Проверка наличия файла
    if os.path.exists(output_path):
        print(f"Файл '{output_path}' уже существует.")
    else:
        print(f"Файл '{output_path}' не найден. Начинаю загрузку...")
        gdown.download(file_url, output_path, quiet=False)
        print(f"Файл '{output_path}' успешно загружен.")

# Указываем URL и путь к файлу
file_url = 'https://drive.google.com/uc?id=15pofNbomaoUap41Rcn1uNGeiJIqFd2qe'
output_file_name = 'wildberries_reviews.csv.gz'  # Укажите реальное имя файла, которое хотите сохранить
output_path = os.path.join(os.getcwd(), output_file_name)  # Полный путь к файлу

download_file_if_not_exists(file_url, output_path)
# Out:
# Файл '/workspace/wildberries_reviews.csv.gz' уже существует.

# %%
import cudf.pandas  # Импортирование cuDF и активация его использования
cudf.pandas.install()  # Установка cuDF как основного интерфейса для pandas
import pandas as pd  # Импортирование pandas после установки cuDF

import os
import yaml
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
from tqdm import tqdm
from IPython.display import display
import numpy as np

# Убедитесь, что у вас есть необходимые пакеты
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Загрузка конфигурации из YAML-файла
CONFIG = yaml.safe_load(open('./reviews_keywords/config.yaml'))

# Словари аспектных групп
aspect_groups_all = {
    'основные характеристики': CONFIG['aspect_groups_main'],
    'электроника и устройства': CONFIG['aspect_groups_devices'],
    'автотовары': CONFIG['aspect_groups_cars'],
    'одежда и обувь': CONFIG['aspect_groups_clothes'],
    'бытовая техника': CONFIG['aspect_groups_appliances'],
    'красота и уход': CONFIG['aspect_groups_beauty'],
    'игрушки и детские товары': CONFIG['aspect_groups_toys'],
    'канцелярия и книги': CONFIG['aspect_groups_books'],
    'мебель и интерьер': CONFIG['aspect_groups_furniture'],
    'сад и огород': CONFIG['aspect_groups_garden'],
}

# Объединение всех аспектов в один словарь
aspect_dict = {}
for category, aspects in aspect_groups_all.items():
    aspect_dict.update(aspects)

# Загрузка данных из CSV-файла, используя cuDF
df_raw = pd.read_csv(output_path,nrows=30000, compression='gzip')

# Отбор первых 3000 записей для ускорения обработки
df = df_raw.head(3000)

# Предобработка текстов (токенизация, лемматизация, удаление стоп-слов)
stop_words = set(stopwords.words('russian'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\W', ' ', text)
    tokens = word_tokenize(text)
    # tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

tqdm.pandas(desc="Предобработка отзывов")
df['processed_review'] = df['review_full_text'].progress_apply(preprocess_text)

# Функция для разметки аспектов на основе словаря
def tag_aspects(text, aspect_dict):
    tagged_aspects = []
    for aspect, keywords in aspect_dict.items():
        for keyword in keywords:
            if keyword in text:
                tagged_aspects.append(aspect)
    return tagged_aspects

# Применение разметки аспектов к каждому обработанному отзыву
tqdm.pandas(desc="Разметка аспектов")
df['tagged_aspects'] = df['processed_review'].progress_apply(lambda x: tag_aspects(x, aspect_dict))

# Просмотр первых нескольких строк после обработки
display(df[['processed_review', 'tagged_aspects']].head())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Предобработка отзывов: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 15014.85it/s]
# Разметка аспектов: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 21702.20it/s]
#                                     processed_review  \
# 0                                    работает хорошо
# 1  пришло быстро все целое на вид завтра буду исп...
# 2  купил на квадр для поднятия отвала установка з...
# 3  лебёдка хорошая но в инструкции ни слова про с...
# 4   всё в комплекте есть инструкция на русском языке
#
#                                       tagged_aspects
# 0                                                 []
# 1                                              [Тип]
# 2                                                 []
# 3                                                 []
# 4  [Инструкция по применению, Рекомендации по при...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from IPython.display import display

# Инициализация TF-IDF векторизатора
vectorizer = TfidfVectorizer(max_features=1000)
X = vectorizer.fit_transform(df['processed_review'])  # Данные уже в pandas, не требуется преобразование

# Применение кластеризации для поиска новых аспектов
num_clusters = 10  # Количество кластеров можно настроить
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
kmeans.fit(X)

# Получение новых аспектов из кластеров
new_aspects = []
for i in tqdm(range(num_clusters), desc="Извлечение новых аспектов"):
    cluster_center = kmeans.cluster_centers_[i]
    closest, _ = pairwise_distances_argmin_min(cluster_center.reshape(1, -1), X)
    aspect_candidate = df['processed_review'].iloc[closest[0]]
    
    # Убираем пустые строки и проверяем на наличие значимого текста
    if aspect_candidate and aspect_candidate.strip():
        new_aspects.append(aspect_candidate)

# Убираем дубликаты, если они есть
new_aspects = list(set(new_aspects))

display("Найденные новые аспекты:")
display(new_aspects)
# Out:
# Извлечение новых аспектов: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 254.83it/s]
# 'Найденные новые аспекты:'
# ['норм', 'упаковали отлично', 'отличный', 'со своей задачей справляется']

# %%
import json
import os
from datetime import datetime

# Пути для сохранения аспектов
new_aspects_file = './new_aspects.json'
blacklist_file = './aspect_blacklist.json'

# Функция для сохранения аспектов в файл
def save_aspects(aspects, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(aspects, file, ensure_ascii=False, indent=4)

# Функция для загрузки аспектов из файла
def load_aspects(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            return json.load(file)
    return []

# Инициализация списка для новых аспектов
new_aspects_list = load_aspects(new_aspects_file)

# Проверка типа загруженных данных
if not isinstance(new_aspects_list, list):
    new_aspects_list = []

# Добавление новых аспектов в список (без дубликатов)
for aspect in new_aspects:
    if aspect not in new_aspects_list:
        new_aspects_list.append(aspect)

# Сохранение новых аспектов в файл
save_aspects(new_aspects_list, new_aspects_file)

# Функция для обзора аспектов и их сортировки в основной словарь или черный список
def review_and_sort_aspects(auto_confirm=False):
    new_aspects = load_aspects(new_aspects_file)
    blacklist = load_aspects(blacklist_file)
    
    updated_aspect_dict = aspect_dict.copy()  # Копируем основной словарь

    # Убедимся, что раздел 'Новые аспекты' существует
    if 'Новые аспекты' not in updated_aspect_dict:
        updated_aspect_dict['Новые аспекты'] = []

    for aspect in new_aspects:
        # Фильтрация аспектов по длине (например, минимум 3 слова)
        if len(aspect.split()) < 3:
            continue
        
        print(f"Новый аспект: {aspect}")
        
        if auto_confirm:
            action = 'a'  # Автоматическое добавление в словарь
        else:
            action = input("Добавить в словарь (a), добавить в черный список (b), пропустить (s): ").lower().strip()
        
        if action == 'a':
            updated_aspect_dict['Новые аспекты'].append(aspect)
        elif action == 'b':
            blacklist.append(aspect)
    
    # Сохраняем обновленный словарь аспектов и черный список
    save_aspects(updated_aspect_dict, new_aspects_file)
    save_aspects(blacklist, blacklist_file)
    print("Обзор завершен. Обновленные аспекты сохранены.")

# Вызов функции для обзора и сортировки с авто-подтверждением
review_and_sort_aspects(auto_confirm=True)
# Out:
# Новый аспект: со своей задачей справляется
# Обзор завершен. Обновленные аспекты сохранены.

# %%
import matplotlib.pyplot as plt
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import TrainerCallback, TrainingArguments, Trainer
from torch.utils.data import Dataset
import torch
import pandas as pd
from IPython.display import display, update_display

# Загрузка предобученной модели и токенизатора BERT
model_name = 'DeepPavlov/rubert-base-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=2)  # num_labels = 2 для двух классов

# Проверка доступности GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Перенос модели на GPU
model = model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using device: cuda

# %%
# # Кастомный класс Dataset
# class ReviewsDataset(Dataset):
#     def __init__(self, texts, labels):
#         self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=128)
#         self.labels = labels

#     def __getitem__(self, idx):
#         item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#         item['labels'] = torch.tensor(self.labels[idx])
#         return item

#     def __len__(self):
#         return len(self.labels)

# # Пример данных для дообучения
# texts = df['processed_review'].tolist()

# # Преобразование меток
# def convert_labels(rating):
#     if rating < 4:
#         return 0  # Негативный
#     else:
#         return 1  # Позитивный

# labels = df['review_rating'].apply(convert_labels).tolist()  # Преобразуем метки в диапазон [0, 1]

# # Создание датасета
# dataset = ReviewsDataset(texts, labels)

# # Настройка параметров обучения
# training_args = TrainingArguments(
#     output_dir='./reviews_keywords/results',
#     num_train_epochs=5,
#     per_device_train_batch_size=64,  # Устанавливаем размер батча на 64
#     save_steps=10_000,
#     save_total_limit=2,
#     logging_steps=10,  # Логирование каждые 10 шагов
#     logging_dir='./reviews_keywords/logs',
#     fp16=True,  # Включение смешанного точного обучения
#     report_to=[]  # Отключаем другие типы логирования
# )

# # Кастомный Trainer с переопределением метода сохранения
# class CustomTrainer(Trainer):
#     def save_model(self, output_dir=None, _internal_call=False):
#         # Преобразование тензоров в непрерывные блоки памяти
#         for param in self.model.parameters():
#             param.data = param.data.contiguous()
#         # Вызов стандартного метода сохранения модели
#         super().save_model(output_dir, _internal_call)

# # Инициализация кастомного Trainer с нашим callback
# trainer = CustomTrainer(
#     model=model,
#     args=training_args,
#     train_dataset=dataset,
# )

# # Запуск дообучения
# train_output = trainer.train()
# train_output

# %%
import torch
from transformers import BertTokenizer, BertModel, BertForSequenceClassification
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import numpy as np
import logging
import nltk

# Загрузка необходимых ресурсов NLTK
nltk.download('stopwords')
nltk.download('wordnet')

# Настройка логирования
log_file_path = './reviews_keywords/logfile.log'
logging.basicConfig(filename=log_file_path, level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Загрузка предобученной модели и токенизатора
model_name = 'DeepPavlov/rubert-base-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
sentiment_model = BertForSequenceClassification.from_pretrained('./reviews_keywords/results/checkpoint-235')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
sentiment_model.to(device)

# Загрузка стоп-слов и инициализация лемматизатора
stop_words = set(stopwords.words('russian'))
lemmatizer = WordNetLemmatizer()

# Функция для нормализации текста (лемматизация и удаление стоп-слов)
def normalize_text(text):
    tokens = [lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words]
    return ' '.join(tokens)

# Функция для получения эмбеддинга текста
def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128)
    inputs = {key: val.to(device) for key, val in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).cpu().numpy().flatten()

# Функция для нормализации вектора
def normalize_vector(vector):
    norm = np.linalg.norm(vector)
    return vector / norm if norm != 0 else vector

# Комбинирование BERT и TF-IDF для получения более точных эмбеддингов
def combine_bert_tfidf(text, tfidf_vectorizer, tfidf_features):
    bert_embedding = get_embedding(text)
    tfidf_vector = tfidf_vectorizer.transform([text]).toarray().flatten()
    combined_vector = np.concatenate((bert_embedding, tfidf_vector), axis=0)
    return combined_vector

# Функция для поиска ближайшей группы по косинусному расстоянию
def find_best_groups(category, aspect_groups, tfidf_vectorizer, tfidf_features, threshold=0.4):
    c_split = category.split("/")
    category = f"{c_split[1]} {c_split[-1]}".lower()
    category_vector = combine_bert_tfidf(category, tfidf_vectorizer, tfidf_features)
    best_similarity = 0
    best_group = None
    
    for group_name in aspect_groups.keys():
        group_vector = combine_bert_tfidf(group_name, tfidf_vectorizer, tfidf_features)
        similarity = np.dot(category_vector, group_vector)
        
        # Логирование similarity score для категорий
        logging.info(f"Category: {category} | Group: {group_name} | Similarity: {similarity}")
        
        if similarity > best_similarity and similarity >= threshold:
            best_similarity = similarity
            best_group = group_name
    
    return ['основные характеристики', best_group] if best_group else ['основные характеристики']

# Функция для поиска ближайшего аспекта
def find_closest_aspect(embedding, aspect_embeddings, threshold=0.4):
    similarities = {}
    for aspect, aspect_emb in aspect_embeddings.items():
        similarity = cosine_similarity(embedding.reshape(1, -1), aspect_emb.reshape(1, -1)).flatten()[0]
        similarities[aspect] = similarity
    
    # Сортировка аспектов по similarity и выбор топ-3
    sorted_aspects = sorted(similarities.items(), key=lambda item: item[1], reverse=True)[:3]
    
    # Логирование топ-3 аспектов
    for aspect, similarity in sorted_aspects:
        logging.info(f"Aspect: {aspect} | Similarity: {similarity}")
    
    # Выбор лучшего аспекта, если его similarity выше порога
    closest_aspect, similarity_score = sorted_aspects[0]
    if similarity_score >= threshold:
        return closest_aspect, similarity_score
    else:
        return "", similarity_score  # Пустое значение, если порог не пройден

# Функция для предсказания тональности
def predict_sentiment(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128).to(device)
    with torch.no_grad():
        outputs = sentiment_model(**inputs)
        sentiment = torch.argmax(outputs.logits, dim=-1).cpu().numpy()
    return 'positive' if sentiment == 1 else 'negative'

# Применение к DataFrame
def process_reviews(df, aspect_groups_all, tfidf_vectorizer, tfidf_features):
    # Инициализируем кэш для аспектов
    aspect_embeddings_cache = {}
    
    # Результаты для каждого отзыва
    all_original_aspects = []
    all_matched_aspects = []
    all_similarity_scores = []
    all_sentiments = []

    categories = df['category'].unique()

    for category in tqdm(categories, desc="Обработка категорий"):
        best_groups = find_best_groups(category, aspect_groups_all, tfidf_vectorizer, tfidf_features)

        if category not in aspect_embeddings_cache:
            aspect_embeddings = {aspect: combine_bert_tfidf(aspect, tfidf_vectorizer, tfidf_features) for group in best_groups for aspect in aspect_groups_all[group].keys()}
            aspect_embeddings_cache[category] = aspect_embeddings
        
        category_df = df[df['category'] == category]
        
        for review in tqdm(category_df['processed_review'], desc=f"Обработка отзывов для категории {category}"):
            original_aspects = []
            matched_aspects = []
            similarity_scores = []
            sentiments = []

            phrases = review.split('. ')
            
            for phrase in phrases:
                normalized_phrase = normalize_text(phrase)
                phrase_embedding = combine_bert_tfidf(normalized_phrase, tfidf_vectorizer, tfidf_features)
                
                # Поиск ближайшего аспекта
                closest_aspect, similarity_score = find_closest_aspect(phrase_embedding, aspect_embeddings_cache[category])
                
                original_aspects.append(phrase)
                matched_aspects.append(closest_aspect)
                similarity_scores.append(similarity_score)
                sentiments.append(predict_sentiment(phrase))
            
            all_original_aspects.append(original_aspects)
            all_matched_aspects.append(matched_aspects)
            all_similarity_scores.append(similarity_scores)
            all_sentiments.append(sentiments)

    # Добавляем результаты в DataFrame
    df['original_aspects'] = all_original_aspects
    df['matched_aspects'] = all_matched_aspects
    df['similarity_score'] = all_similarity_scores
    df['predicted_sentiment'] = all_sentiments

    return df

# Обучение TF-IDF Vectorizer на текстах отзывов
def train_tfidf(df):
    processed_texts = df['processed_review'].apply(normalize_text)
    tfidf_vectorizer = TfidfVectorizer(max_features=5000)
    tfidf_features = tfidf_vectorizer.fit_transform(processed_texts)
    return tfidf_vectorizer, tfidf_features

# Применение процесса к части DataFrame
start_idx = 3000
end_idx = 5000
test_df = df_raw.iloc[start_idx:end_idx].copy()
test_df['processed_review'] = test_df['review_full_text'].apply(preprocess_text)

# Обучение TF-IDF на данных
tfidf_vectorizer, tfidf_features = train_tfidf(test_df)

# Обработка и анализ отзывов
test_df = process_reviews(test_df, aspect_groups_all, tfidf_vectorizer, tfidf_features)

# Сохранение результатов
output_path = 'path_to_save_results.csv'
test_df.to_csv(output_path, index=False)
print(f"Результаты сохранены в {output_path}")

# Просмотр первых нескольких строк с результатами
display(test_df[['review_full_text', 'processed_review', 'original_aspects', 'matched_aspects', 'similarity_score', 'predicted_sentiment']].head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Обработка отзывов для категории /Автотовары/Автокосметика и автохимия/Герметики автомобильные: 100%|████████████████████████████████████████████████████████████████████████████████████| 275/275 [00:06<00:00, 42.50it/s]
# Обработка отзывов для категории /Автотовары/Автокосметика и автохимия/Очистители автомобильные: 100%|█████████████████████████████████████████████████████████████████████████████████| 1253/1253 [00:29<00:00, 42.33it/s]
# Обработка отзывов для категории /Автотовары/Автокосметика и автохимия/Присадки: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 472/472 [00:11<00:00, 42.71it/s]
# Обработка категорий: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:48<00:00, 16.24s/it]
# Результаты сохранены в path_to_save_results.csv
#                                        review_full_text  \
# 3000  Помогает при малых течах. Радиаторы печки и ос...
# 3001  Отличная цена и хорошее качество. Рекомендую. ...
# 3002  Всё супер течь перестало! Печка пока греет) не...
# 3003   Герметик нормальный течь устранил печка не течёт
# 3004  Долго не могли сами найти утечку антифриза. Ка...
#
#                                        processed_review  \
# 3000  помогает при малых течах радиаторы печки и осн...
# 3001  отличная цена и хорошее качество рекомендую в ...
# 3002  всё супер течь перестало печка пока греет не ч...
# 3003   герметик нормальный течь устранил печка не течёт
# 3004  долго не могли сами найти утечку антифриза как...
#
#                                        original_aspects matched_aspects  \
# 3000  [помогает при малых течах радиаторы печки и ос...              []
# 3001  [отличная цена и хорошее качество рекомендую в...              []
# 3002  [всё супер течь перестало печка пока греет не ...              []
# 3003  [герметик нормальный течь устранил печка не те...              []
# 3004  [долго не могли сами найти утечку антифриза ка...              []
#
#            similarity_score predicted_sentiment
# 3000   [0.2703434153896052]          [positive]
# 3001  [0.30997570029390775]          [positive]
# 3002    [0.246963186146878]          [positive]
# 3003  [0.31199636936085295]          [positive]
# 3004   [0.2552704111055252]          [positive]

# %%
# Фильтруем строки, где matched_aspects не содержит только пустые строки
filtered_df = test_df[test_df['matched_aspects'].apply(lambda x: any(item.strip() for item in x))]
filtered_df
# Out:
#       Unnamed: 0                                   review_full_text  \
# 3007        3033                   Заказывал синий а пришёл красный
# 3009        3035               Помогло. На 2 день течь прекратилась
# 3011        3037                    Товар соответствует написанному
# 3013        3039                        Пришло вовремя, минусов нет
# 3015        3041              Не работает ,трата времени и денег!!!
# ...          ...                                                ...
# 4991        5047  Ни о чем. Как было, так и осталось.\nНе ведитесь.
# 4993        5049                              Хорошая,рабочая штука
# 4997        5053                              муж остался довольным
# 4998        5054  Доставка быстрая. Заказываем не в первый раз. ...
# 4999        5055                     Классная вещь уничтожила мотор
#
#       review_rating                                            product  \
# 3007              5    LAVR / Индикатор утечек системы охлаждения авто
# 3009              5    LAVR / Индикатор утечек системы охлаждения авто
# 3011              5    LAVR / Индикатор утечек системы охлаждения авто
# 3013              5    LAVR / Индикатор утечек системы охлаждения авто
# 3015              1    LAVR / Индикатор утечек системы охлаждения авто
# ...             ...                                                ...
# 4991              1  FAZZH-1 Жидкая гильзовка / Присадка в масло дв...
# 4993              5  FAZZH-1 Жидкая гильзовка / Присадка в масло дв...
# 4997              5  FAZZH-1 Жидкая гильзовка / Присадка в масло дв...
# 4998              5  FAZZH-1 Жидкая гильзовка / Присадка в масло дв...
# 4999              1  FAZZH-1 Жидкая гильзовка / Присадка в масло дв...
#
#                                                category  \
# 3007  /Автотовары/Автокосметика и автохимия/Герметик...
# 3009  /Автотовары/Автокосметика и автохимия/Герметик...
# 3011  /Автотовары/Автокосметика и автохимия/Герметик...
# 3013  /Автотовары/Автокосметика и автохимия/Герметик...
# 3015  /Автотовары/Автокосметика и автохимия/Герметик...
# ...                                                 ...
# 4991     /Автотовары/Автокосметика и автохимия/Присадки
# 4993     /Автотовары/Автокосметика и автохимия/Присадки
# 4997     /Автотовары/Автокосметика и автохимия/Присадки
# 4998     /Автотовары/Автокосметика и автохимия/Присадки
# 4999     /Автотовары/Автокосметика и автохимия/Присадки
#
#                                                     url  \
# 3007  https://www.wildberries.ru/catalog/91102762/fe...
# 3009  https://www.wildberries.ru/catalog/91102762/fe...
# 3011  https://www.wildberries.ru/catalog/91102762/fe...
# 3013  https://www.wildberries.ru/catalog/91102762/fe...
# 3015  https://www.wildberries.ru/catalog/91102762/fe...
# ...                                                 ...
# 4991  https://www.wildberries.ru/catalog/90516640/fe...
# 4993  https://www.wildberries.ru/catalog/90516640/fe...
# 4997  https://www.wildberries.ru/catalog/90516640/fe...
# 4998  https://www.wildberries.ru/catalog/90516640/fe...
# 4999  https://www.wildberries.ru/catalog/90516640/fe...
#
#                                        processed_review  \
# 3007                   заказывал синий а пришёл красный
# 3009                помогло на 2 день течь прекратилась
# 3011                    товар соответствует написанному
# 3013                         пришло вовремя минусов нет
# 3015                  не работает трата времени и денег
# ...                                                 ...
# 4991       ни о чем как было так и осталось не ведитесь
# 4993                              хорошая рабочая штука
# 4997                              муж остался довольным
# 4998  доставка быстрая заказываем не в первый раз му...
# 4999                     классная вещь уничтожила мотор
#
#                                        original_aspects  \
# 3007                 [заказывал синий а пришёл красный]
# 3009              [помогло на 2 день течь прекратилась]
# 3011                  [товар соответствует написанному]
# 3013                       [пришло вовремя минусов нет]
# 3015                [не работает трата времени и денег]
# ...                                                 ...
# 4991     [ни о чем как было так и осталось не ведитесь]
# 4993                            [хорошая рабочая штука]
# 4997                            [муж остался довольным]
# 4998  [доставка быстрая заказываем не в первый раз м...
# 4999                   [классная вещь уничтожила мотор]
#
#               matched_aspects       similarity_score predicted_sentiment
# 3007                   [Цвет]   [0.5246957163052979]          [positive]
# 3009           [Режим работы]   [0.4814036546831907]          [positive]
# 3011                  [Товар]  [0.47408719607690364]          [positive]
# 3013      [Количество дверей]   [0.5202871325473533]          [positive]
# 3015  [Максимальная нагрузка]   [0.5342549769557916]          [negative]
# ...                       ...                    ...                 ...
# 4991             [Назначение]   [0.5816369400540927]          [negative]
# 4993    [Рабочая температура]   [0.6229619398602416]          [positive]
# 4997      [Модель автомобиля]   [0.4501992306358398]          [positive]
# 4998          [Производитель]   [0.4091676371304376]          [positive]
# 4999      [Модель автомобиля]   [0.5882458688168184]          [positive]
#
# [1024 rows x 11 columns]

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
from transformers import BertTokenizer, BertModel, BertForSequenceClassification
import torch
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from IPython.display import display, HTML

# Шаг 1: Загрузка необходимых ресурсов NLTK
nltk.download('stopwords')
nltk.download('wordnet')

# Шаг 2: Настройка предобработки текста
stop_words = set(stopwords.words('russian'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)  # Удаляем пунктуацию
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(words)

# Шаг 3: Загрузка предобученных моделей BERT
model_name = 'DeepPavlov/rubert-base-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
sentiment_model = BertForSequenceClassification.from_pretrained('blanchefort/rubert-base-cased-sentiment')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
sentiment_model.to(device)

# Шаг 4: Извлечение эмбеддингов текста с использованием BERT
def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128)
    inputs = {key: val.to(device) for key, val in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).cpu().numpy().flatten()

# Шаг 5: Создание и обучение модели Word2Vec
def train_word2vec(df):
    sentences = [review.split() for review in df['processed_review']]
    model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)
    return model

# Шаг 6: Фильтрация неинформативных слов с использованием Word2Vec
def phrase_similarity(phrase, word2vec_model, target_word):
    words = phrase.split()
    similarities = []
    for word in words:
        if word in word2vec_model.wv:
            similarities.append(word2vec_model.wv.similarity(word, target_word))
    if similarities:
        return np.mean(similarities)
    else:
        return 0

def filter_non_informative(aspects, word2vec_model, threshold=0.3):  # Уменьшен порог фильтрации
    informative_aspects = []
    for aspect in aspects:
        quality_sim = phrase_similarity(aspect, word2vec_model, 'качество')
        works_sim = phrase_similarity(aspect, word2vec_model, 'работает')
        if quality_sim > threshold or works_sim > threshold:
            informative_aspects.append(aspect)
    return informative_aspects

# Шаг 7: Извлечение аспектов с использованием TF-IDF и фильтрации с Word2Vec
def extract_aspects_tfidf(df, text_column='processed_review', num_terms=5):
    vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 3), stop_words=stop_words)  # Увеличен диапазон n-грамм
    tfidf_matrix = vectorizer.fit_transform(df[text_column])
    feature_names = vectorizer.get_feature_names_out()

    aspects = {}
    
    for cluster in df['aspect_cluster'].unique():
        cluster_reviews = df[df['aspect_cluster'] == cluster][text_column]
        cluster_matrix = vectorizer.transform(cluster_reviews)
        mean_tfidf = cluster_matrix.mean(axis=0).A1
        top_indices = mean_tfidf.argsort()[-num_terms:][::-1]
        top_terms = [feature_names[i] for i in top_indices]
        aspects[cluster] = top_terms
    
    return aspects

# Шаг 8: Кластеризация аспектов и фильтрация с использованием Word2Vec
def cluster_aspects(df, num_clusters=5):
    embeddings = np.array([get_embedding(review) for review in df['processed_review']])
    
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    df['aspect_cluster'] = kmeans.fit_predict(embeddings)

    word2vec_model = train_word2vec(df)
    aspects = extract_aspects_tfidf(df)
    
    # Фильтрация аспектов через Word2Vec
    filtered_aspects = {cluster: filter_non_informative(terms, word2vec_model) for cluster, terms in aspects.items()}
    
    # Преобразуем аспекты в DataFrame с двумя столбцами
    aspect_clusters = pd.DataFrame(list(filtered_aspects.items()), columns=['aspect_cluster', 'common_terms'])
    
    return aspect_clusters, df

# Шаг 9: Предсказание тональности с учетом рейтинга
def predict_sentiment(text, rating):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128).to(device)
    with torch.no_grad():
        outputs = sentiment_model(**inputs)
        sentiment = torch.argmax(outputs.logits, dim=-1).cpu().numpy()
    
    # Учет рейтинга отзыва
    if rating >= 4 and sentiment == 0:
        return 'positive'
    return 'positive' if sentiment == 1 else 'negative'

# Шаг 10: Анализ аспектов и тональности
def analyze_sentiments(df):
    df['sentiment'] = df.apply(lambda row: predict_sentiment(row['processed_review'], row['review_rating']), axis=1)
    aspect_summary = df.groupby(['aspect_cluster', 'sentiment'])['processed_review'].count().unstack(fill_value=0)
    
    # Проверка наличия столбцов 'positive' и 'negative'
    if 'positive' not in aspect_summary.columns:
        aspect_summary['positive'] = 0
    if 'negative' not in aspect_summary.columns:
        aspect_summary['negative'] = 0
        
    aspect_summary['total'] = aspect_summary.sum(axis=1)
    return aspect_summary.sort_values('total', ascending=False)

# Шаг 11: Предобработка текстов и кластеризация
df = df_raw[3000:3300]  # Замените df_raw на ваш DataFrame с отзывами
df['processed_review'] = df['review_full_text'].apply(preprocess_text)
aspect_clusters, df = cluster_aspects(df, num_clusters=5)
aspect_summary = analyze_sentiments(df)

# Шаг 12: Подготовка данных для презентации клиенту
def prepare_presentation(aspect_clusters, aspect_summary):
    display(HTML("<h2>Ключевые аспекты товара</h2>"))
    
    for i, row in aspect_clusters.iterrows():
        aspect_terms = ', '.join(row['common_terms'])
        display(HTML(f"<h3>Кластер {row['aspect_cluster']}</h3>"))
        display(HTML(f"<p><strong>Ключевые аспекты:</strong> {aspect_terms}</p>"))
        
        cluster_summary = aspect_summary.loc[[row['aspect_cluster']]]
        display(cluster_summary.style.set_caption("Распределение отзывов по тональности").background_gradient(cmap='coolwarm'))
    
    display(HTML("<h2>Рекомендации</h2>"))
    rec_text = ("<p>Проанализируйте товары с преобладанием негативных аспектов. "
                "Если такие аспекты связаны с качеством продукции, рассмотрите возможность работы с поставщиком или поиска альтернативных продуктов.</p>"
                "<p>Используйте положительные аспекты для маркетинговых стратегий, подчеркивая сильные стороны товара.</p>")
    display(HTML(rec_text))

# Шаг 13: Презентация результатов клиенту
prepare_presentation(aspect_clusters, aspect_summary)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <h2>Ключевые аспекты товара</h2>
# <h3>Кластер 3</h3>
# <p><strong>Ключевые аспекты:</strong> </p>
# <style type="text/css">
# #T_4db02_row0_col0, #T_4db02_row0_col1, #T_4db02_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4db02">
#   <caption>Распределение отзывов по тональности</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4db02_level0_col0" class="col_heading level0 col0" >negative</th>
#       <th id="T_4db02_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_4db02_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4db02_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_4db02_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_4db02_row0_col1" class="data row0 col1" >32</td>
#       <td id="T_4db02_row0_col2" class="data row0 col2" >46</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Кластер 1</h3>
# <p><strong>Ключевые аспекты:</strong> </p>
# <style type="text/css">
# #T_9cba6_row0_col0, #T_9cba6_row0_col1, #T_9cba6_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9cba6">
#   <caption>Распределение отзывов по тональности</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cba6_level0_col0" class="col_heading level0 col0" >negative</th>
#       <th id="T_9cba6_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_9cba6_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cba6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9cba6_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_9cba6_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_9cba6_row0_col2" class="data row0 col2" >21</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Кластер 2</h3>
# <p><strong>Ключевые аспекты:</strong> </p>
# <style type="text/css">
# #T_64c1a_row0_col0, #T_64c1a_row0_col1, #T_64c1a_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64c1a">
#   <caption>Распределение отзывов по тональности</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64c1a_level0_col0" class="col_heading level0 col0" >negative</th>
#       <th id="T_64c1a_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_64c1a_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64c1a_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_64c1a_row0_col0" class="data row0 col0" >26</td>
#       <td id="T_64c1a_row0_col1" class="data row0 col1" >36</td>
#       <td id="T_64c1a_row0_col2" class="data row0 col2" >62</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Кластер 0</h3>
# <p><strong>Ключевые аспекты:</strong> работает</p>
# <style type="text/css">
# #T_8dbe2_row0_col0, #T_8dbe2_row0_col1, #T_8dbe2_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8dbe2">
#   <caption>Распределение отзывов по тональности</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dbe2_level0_col0" class="col_heading level0 col0" >negative</th>
#       <th id="T_8dbe2_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_8dbe2_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dbe2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dbe2_row0_col0" class="data row0 col0" >70</td>
#       <td id="T_8dbe2_row0_col1" class="data row0 col1" >95</td>
#       <td id="T_8dbe2_row0_col2" class="data row0 col2" >165</td>
#     </tr>
#   </tbody>
# </table>
# <h3>Кластер 4</h3>
# <p><strong>Ключевые аспекты:</strong> качество</p>
# <style type="text/css">
# #T_f166f_row0_col0, #T_f166f_row0_col1, #T_f166f_row0_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f166f">
#   <caption>Распределение отзывов по тональности</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f166f_level0_col0" class="col_heading level0 col0" >negative</th>
#       <th id="T_f166f_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_f166f_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f166f_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_f166f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f166f_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_f166f_row0_col2" class="data row0 col2" >6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Рекомендации</h2>
# <p>Проанализируйте товары с преобладанием негативных аспектов. Если такие аспекты связаны с качеством продукции, рассмотрите возможность работы с поставщиком или поиска альтернативных продуктов.</p><p>Используйте положительные аспекты для маркетинговых стратегий, подчеркивая сильные стороны товара.</p>

# %%
df_raw[3000:3100].to_csv("./reviews_keywords/leak.csv", index=False)

# %%
# Импорт необходимых библиотек
import cudf.pandas  # Импортирование cuDF и активация его использования
cudf.pandas.install()  # Установка cuDF как основного интерфейса для pandas

# %%
# Импорт необходимых библиотек
import pandas as pd
import re
import time
from tqdm import tqdm  # Прогресс-бар
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import spacy
from textblob import TextBlob
from transformers import pipeline, AutoTokenizer, AutoModel, AutoModelForSequenceClassification
from datasets import Dataset  # Правильный импорт для Hugging Face Datasets
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from bertopic import BERTopic
import matplotlib.pyplot as plt
import seaborn as sns
import stanza

# Загрузка списка стоп-слов для русского языка из NLTK
nltk_stop_words = stopwords.words('russian')

# Загрузка данных из CSV-файла, используя cuDF
df_raw = pd.read_csv("./wildberries_reviews.csv.gz", nrows=30000, compression='gzip')
data = df_raw[3000:3500]

# Предобработка текста с использованием различных технологий

# NLTK
def preprocess_text_nltk(text):
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words('russian'))
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(tokens)

tqdm.pandas()  # Для отображения прогресса
data['cleaned_text_nltk'] = data['review_full_text'].progress_apply(preprocess_text_nltk)

# SpaCy
nlp_spacy = spacy.load("ru_core_news_lg")  # large модель spaCy
def preprocess_text_spacy(text):
    doc = nlp_spacy(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return ' '.join(tokens)

data['cleaned_text_spacy'] = data['review_full_text'].progress_apply(preprocess_text_spacy)

# Stanza
nlp_stanza = stanza.Pipeline("ru", processors="tokenize,lemma")
def preprocess_text_stanza(text):
    doc = nlp_stanza(text)
    tokens = [word.lemma for sent in doc.sentences for word in sent.words if word.text not in stop_words]
    return ' '.join(tokens)

data['cleaned_text_stanza'] = data['review_full_text'].progress_apply(preprocess_text_stanza)

# Создание датасета Hugging Face для пакетной обработки
dataset = Dataset.from_pandas(data[['review_full_text', 'cleaned_text_spacy']])

# Hugging Face (используем модель `rubert-base-cased`)
tokenizer_hf = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")  # Base модель
model_hf = AutoModelForSequenceClassification.from_pretrained("DeepPavlov/rubert-base-cased")
hf_pipeline = pipeline("sentiment-analysis", model=model_hf, tokenizer=tokenizer_hf, device=0)  # Указание на GPU

# Применение модели для извлечения аспектов с помощью Hugging Face в пакетном режиме
candidate_labels = ["качество", "цена", "функциональность", "упаковка"]
aspect_pipeline = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device=0)  # Указание на GPU

# Определение функции для обработки батчей
def extract_aspects_batch(batch):
    texts = batch['cleaned_text_spacy']
    batch_aspects = []
    for text in texts:
        if not text.strip():
            batch_aspects.append([])
        else:
            result = aspect_pipeline(text, candidate_labels=candidate_labels)
            if not isinstance(result, list):
                result = [result]  # Преобразуем в список
            batch_aspects.append(result)
    return {'aspects_hf': batch_aspects}

# Применение пакетной обработки
dataset = dataset.map(extract_aspects_batch, batched=True, batch_size=8)


# Добавляем результаты обратно в DataFrame
data['aspects_hf'] = dataset['aspects_hf']

# Анализ тональности с использованием TextBlob
data['sentiment_textblob'] = data['cleaned_text_nltk'].progress_apply(lambda x: TextBlob(x).sentiment.polarity)

# Анализ аспектов и тональности с использованием rubert-base-cased
def sentiment_analysis_batch(batch):
    return {'sentiment_rubert': hf_pipeline(batch['review_full_text'])}

dataset = dataset.map(sentiment_analysis_batch, batched=True, batch_size=8)
data['sentiment_rubert'] = dataset['sentiment_rubert']

# Topic Modeling с использованием Gensim LDA
# Используем собственный список стоп-слов для русского языка
russian_stop_words = stopwords.words('russian')
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words=russian_stop_words)
dtm = vectorizer.fit_transform(data['cleaned_text_nltk'])
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_model.fit(dtm)

# Функция для отображения тем
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

display_topics(lda_model, vectorizer.get_feature_names_out(), 10)

# Используем модель `DeepPavlov/rubert-base-cased` для эмбеддингов с поддержкой GPU
tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")
model = AutoModel.from_pretrained("DeepPavlov/rubert-base-cased").to("cuda")  # Переносим модель на GPU

# Функция для генерации эмбеддингов на GPU
def embed_texts(texts):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True).to("cuda")
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state.mean(dim=1)
    return embeddings.cpu().numpy()  # Возвращаем эмбеддинги на CPU для совместимости с BERTopic

# Генерация эмбеддингов для текста
embeddings = embed_texts(data['cleaned_text_spacy'].tolist())

# Создание модели BERTopic с пользовательскими стоп-словами
vectorizer_model = CountVectorizer(stop_words=nltk_stop_words)
topic_model = BERTopic(language="russian", vectorizer_model=vectorizer_model)

# Обучение модели BERTopic на эмбеддингах
topics, probs = topic_model.fit_transform(data['cleaned_text_spacy'], embeddings)


# Вывод топ-10 тем
print("Top 10 topics from BERTopic:")
print(topic_model.get_topic_info().head(10))

# Сравнение производительности технологий
def time_function(func, *args):
    start = time.time()
    func(*args)
    end = time.time()
    return end - start

# Проверяем, существует ли индекс 0
if len(data) > 0:
    nltk_time = time_function(preprocess_text_nltk, data['review_full_text'].iloc[0])  # Используем iloc для безопасного доступа
    spacy_time = time_function(preprocess_text_spacy, data['review_full_text'].iloc[0])
    stanza_time = time_function(preprocess_text_stanza, data['review_full_text'].iloc[0])

    display(f"NLTK processing time: {nltk_time:.4f} seconds")
    display(f"SpaCy processing time: {spacy_time:.4f} seconds")
    display(f"Stanza processing time: {stanza_time:.4f} seconds")
else:
    display("Dataframe is empty or has no rows with index 0")

# Вывод финальных результатов
if len(data) > 0:
    display(data.head())
else:
    display("No data available for displaying results")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 5924.91it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:02<00:00, 204.99it/s]
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 70.23it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 13387.67it/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Topic 0:
# хороший чистит очиститель герметик отличный справился отлично очень задачей спасибо
# Topic 1:
# всё течь супер пришло рекомендую герметик целое радиатор нагар отлично
# Topic 2:
# норм ещё доставка советую быстрая отлично дроссель немного очень товар
# Topic 3:
# отлично спасибо работает рекомендую товар всё упаковано быстро средство ок
# Topic 4:
# упаковка отличный товар качество прозрачный герметика хорошая герметик сразу доставку
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Top 10 topics from BERTopic:
#    Topic  Count                                       Name  \
# 0     -1      6                           -1_ок_очистила__
# 1      0    206  0_герметик_спасибо_радиатор_рекомендовать
# 2      1    195          1_хороший_работать_чистит_отлично
# 3      2     21         2_отличный_нормальный_херня_полный
# 4      3     18                  3_норм_супер_ерунда_норма
# 5      4     14    4_течь_прекратиться_устранять_нанесение
# 6      5     14                      5_время_целый_прийти_
# 7      6     14           6_класс_работать_прийти_отличный
# 8      7     12        7_работвет_помогать_помочь_описание
#
#                                       Representation  \
# 0                     [ок, очистила, , , , , , , , ]
# 1  [герметик, спасибо, радиатор, рекомендовать, х...
# 2  [хороший, работать, чистит, отлично, прийти, р...
# 3  [отличный, нормальный, херня, полный, брать, т...
# 4  [норм, супер, ерунда, норма, топ, рад, 100, ка...
# 5  [течь, прекратиться, устранять, нанесение, мом...
# 6               [время, целый, прийти, , , , , , , ]
# 7    [класс, работать, прийти, отличный, , , , , , ]
# 8  [работвет, помогать, помочь, описание, соответ...
#
#                                  Representative_Docs
# 0                                       [ок, ок, ок]
# 1  [отлично спасибо 👍 👍 👍 продавец рекомендовать,...
# 2  [отлично работать спасибо, чистит отлично реко...
# 3                     [отличный, отличный, отличный]
# 4                                 [норм, норм, норм]
# 5  [помочь 2 день течь прекратиться, залить течь ...
# 6                [целый, прийти время, прийти время]
# 7  [работать 👍 👍 👍 👍 👍, работать 👍 👍 👍 👍 👍, класс...
# 8  [работвет, соответствовать описание, соответст...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/cudf/core/series.py:389, in _SeriesLocIndexer._loc_to_iloc(self, arg)
#     388 if (n := len(indices)) == 0:
# --> 389     raise KeyError("Label scalar is out of bounds")
#     390 elif n == 1:
#
# KeyError: 'Label scalar is out of bounds'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/cudf/core/series.py:305, in _SeriesLocIndexer.__getitem__(self, arg)
#     304 try:
# --> 305     arg = self._loc_to_iloc(arg)
#     306 except (TypeError, KeyError, IndexError, ValueError):
#
# File /opt/conda/lib/python3.10/site-packages/cudf/core/series.py:395, in _SeriesLocIndexer._loc_to_iloc(self, arg)
#     394     except (TypeError, KeyError, IndexError, ValueError):
# --> 395         raise KeyError("Label scalar is out of bounds")
#     397 elif isinstance(arg, slice):
#
# KeyError: 'Label scalar is out of bounds'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:896, in _fast_slow_function_call(func, *args, **kwargs)
#     895 fast_args, fast_kwargs = _fast_arg(args), _fast_arg(kwargs)
# --> 896 result = func(*fast_args, **fast_kwargs)
#     897 if result is NotImplemented:
#     898     # try slow path
#
# File /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30, in call_operator(fn, args, kwargs)
#      29 def call_operator(fn, args, kwargs):
# ---> 30     return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     115 libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116 result = func(*args, **kwargs)
#     117 libnvtx_pop_range(self.domain.handle)
#
# File /opt/conda/lib/python3.10/site-packages/cudf/core/series.py:1354, in Series.__getitem__(self, arg)
#    1353 else:
# -> 1354     return self.loc[arg]
#
# File /opt/conda/lib/python3.10/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     115 libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116 result = func(*args, **kwargs)
#     117 libnvtx_pop_range(self.domain.handle)
#
# File /opt/conda/lib/python3.10/site-packages/cudf/core/series.py:307, in _SeriesLocIndexer.__getitem__(self, arg)
#     306 except (TypeError, KeyError, IndexError, ValueError):
# --> 307     raise KeyError(arg)
#     309 return self._frame.iloc[arg]
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 156
#     153     end = time.time()
#     154     return end - start
# --> 156 nltk_time = time_function(preprocess_text_nltk, data['review_full_text'][0])
#     157 spacy_time = time_function(preprocess_text_spacy, data['review_full_text'][0])
#     158 stanza_time = time_function(preprocess_text_stanza, data['review_full_text'][0])
#
# File /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:699, in _CallableProxyMixin.__call__(self, *args, **kwargs)
#     698 def __call__(self, *args, **kwargs) -> Any:
# --> 699     result, _ = _fast_slow_function_call(
#     700         # We cannot directly call self here because we need it to be
#     701         # converted into either the fast or slow object (by
#     702         # _fast_slow_function_call) to avoid infinite recursion.
#     703         # TODO: When Python 3.11 is the minimum supported Python version
#     704         # this can use operator.call
#     705         call_operator,
#     706         self,
#     707         args,
#     708         kwargs,
#     709     )
#     710     return result
#
# File /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:909, in _fast_slow_function_call(func, *args, **kwargs)
#     907         slow_args, slow_kwargs = _slow_arg(args), _slow_arg(kwargs)
#     908         with disable_module_accelerator():
# --> 909             result = func(*slow_args, **slow_kwargs)
#     910 return _maybe_wrap_result(result, func, *args, **kwargs), fast
#
# File /opt/conda/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:30, in call_operator(fn, args, kwargs)
#      29 def call_operator(fn, args, kwargs):
# ---> 30     return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/range.py:393, in RangeIndex.get_loc(self, key, method, tolerance)
#     391         return self._range.index(new_key)
#     392     except ValueError as err:
# --> 393         raise KeyError(key) from err
#     394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# KeyError: 0

# %%
import pandas as pd
import re
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from bertopic import BERTopic
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
from sklearn.decomposition import NMF
from collections import Counter

# Загрузка данных
df_raw = pd.read_csv("./wildberries_reviews.csv.gz", nrows=30000, compression='gzip')
data = df_raw[3000:3500]

# Очистка текста
def clean_text(text):
    text = re.sub(r'\n', ' ', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = text.lower()
    return text

data['cleaned_text'] = data['review_full_text'].apply(clean_text)

# Группировка отзывов по товарам
grouped_data = data.groupby('product')['cleaned_text'].apply(lambda x: ' '.join(x)).reset_index()

# Токенизация и удаление стоп-слов
stop_words = set(stopwords.words('russian'))
grouped_data['tokens'] = grouped_data['cleaned_text'].apply(lambda x: [word for word in word_tokenize(x) if word not in stop_words])

# Лемматизация с использованием spaCy
nlp = spacy.load("ru_core_news_lg")

def lemmatize_text(tokens):
    doc = nlp(' '.join(tokens))
    return [token.lemma_ for token in doc]

tqdm.pandas()
grouped_data['lemmatized_tokens'] = grouped_data['tokens'].progress_apply(lemmatize_text)

# TF-IDF для выделения важных слов с использованием биграмм
tfidf_vectorizer = TfidfVectorizer(max_features=50, ngram_range=(1, 2))
tfidf_matrix = tfidf_vectorizer.fit_transform(grouped_data['cleaned_text'])

# Получение списка ключевых слов для каждого товара
feature_names = tfidf_vectorizer.get_feature_names_out()

def get_top_keywords(tfidf_row, feature_names, top_n=10):
    top_indices = tfidf_row.argsort()[-top_n:][::-1]
    return [feature_names[i] for i in top_indices]

grouped_data['tfidf_keywords'] = [get_top_keywords(row, feature_names) for row in tfidf_matrix.toarray()]

# Использование LDA для тематики
dictionary = Dictionary(grouped_data['lemmatized_tokens'])
corpus = [dictionary.doc2bow(text) for text in grouped_data['lemmatized_tokens']]
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=10, random_state=42)
grouped_data['lda_topics'] = grouped_data['lemmatized_tokens'].apply(lambda x: lda_model.get_document_topics(dictionary.doc2bow(x)))

# Использование BERTopic для дополнительных тем
bertopic_model = BERTopic(language="russian")
grouped_data['bertopic_topics'] = bertopic_model.fit_transform(grouped_data['cleaned_text'])[0]

# Использование NMF для выделения тем
nmf_model = NMF(n_components=10, random_state=42)
nmf_matrix = nmf_model.fit_transform(tfidf_matrix)
grouped_data['nmf_topics'] = [nmf_matrix[i].argsort()[-1] for i in range(nmf_matrix.shape[0])]

# Использование сентимент-анализа с дообученной моделью
tokenizer_hf = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")
model_hf = AutoModelForSequenceClassification.from_pretrained("cointegrated/rubert-tiny-sentiment-balanced")
hf_pipeline = pipeline("sentiment-analysis", model=model_hf, tokenizer=tokenizer_hf)

def process_text_with_pipeline(text, pipeline):
    max_length = 512
    tokens = tokenizer_hf.encode(text, truncation=False)
    results = []

    # Разбиваем текст на сегменты
    for i in range(0, len(tokens), max_length):
        chunk = tokens[i:i+max_length]
        if len(chunk) == 0:
            continue  # Пропускаем пустые сегменты
        text_chunk = tokenizer_hf.decode(chunk, skip_special_tokens=True)
        try:
            result = pipeline(text_chunk)[0]['label']
        except IndexError:
            continue  # Пропускаем сегменты, которые не могут быть обработаны
        results.append(result)
    
    # Определяем доминирующий сентимент
    sentiment_map = {"LABEL_1": "Положительный", "LABEL_0": "Отрицательный"}
    if results:
        dominant_sentiment = max(set(results), key=results.count)
        return sentiment_map.get(dominant_sentiment, "Нейтральный")
    else:
        return "Нейтральный"

grouped_data['hf_sentiment'] = grouped_data['cleaned_text'].apply(lambda x: process_text_with_pipeline(x, hf_pipeline))

# Генерация ключевых мыслей с учетом частоты ключевых слов и сентимента
def generate_key_thoughts_with_nmf(row):
    tfidf_keywords = row['tfidf_keywords']
    hf_sentiment = row['hf_sentiment']
    nmf_topic = row['nmf_topics']

    # Частота ключевых слов
    word_counts = Counter(tfidf_keywords)
    most_common_words = word_counts.most_common(3)

    key_thoughts = f"Основные характеристики товара:\nКлючевые слова: {', '.join(tfidf_keywords)}\nЧасто встречающиеся слова: {', '.join([word for word, _ in most_common_words])}\nNMF Тема: {nmf_topic}\nSentiment: {hf_sentiment}"
    
    positive_aspects = []
    negative_aspects = []
    
    if 'Положительный' in hf_sentiment:
        positive_aspects.append("Положительный сантимент")
    if 'Отрицательный' in hf_sentiment:
        negative_aspects.append("Отрицательный сантимент")

    return key_thoughts, positive_aspects, negative_aspects

grouped_data['key_thoughts'], grouped_data['positive_aspects'], grouped_data['negative_aspects'] = zip(*grouped_data.apply(generate_key_thoughts_with_nmf, axis=1))

# Формирование отчета
for index, row in grouped_data.iterrows():
    print(f"Товар: {row['product']}")
    print(f"Ключевая мысль: {row['key_thoughts']}")
    print("Положительные аспекты:")
    for aspect in row['positive_aspects']:
        print(f"- {aspect}")
    print("Отрицательные аспекты:")
    for aspect in row['negative_aspects']:
        print(f"- {aspect}")
    print("\n")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 13.22it/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Товар: 3TON / Очиститель карбюратора и дроссельной заслонки
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: отлично, очиститель, чистит, всё, товар, спасибо, средство, хороший, рекомендую, супер
# Часто встречающиеся слова: отлично, очиститель, чистит
# NMF Тема: 2
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: AG TECH / Очиститель дроссельной заслонки и карбюратора 650мл
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: на, рекомендую, не, чистит, отлично, хорошо, очиститель, всё, товар, спасибо
# Часто встречающиеся слова: на, рекомендую, не
# NMF Тема: 2
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: Abro / 404 Герметик радиатора (20гр.) США AB-404-R
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: не, отлично, всё, течь, работает, спасибо, хорошо, для, рекомендую, герметик
# Часто встречающиеся слова: не, отлично, всё
# NMF Тема: 8
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: FELIX (авто) / Герметик системы охлаждения Felix, 500 мл
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: работает, товар, за, не, что, как, очиститель, очень, отличный, отлично
# Часто встречающиеся слова: работает, товар, за
# NMF Тема: 5
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: Grand Caratt / Герметик-прокладка, силиконовый, 50 г, красный
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: не, герметик, на, хорошо, так, но, упаковка, для, всё, быстро
# Часто встречающиеся слова: не, герметик, на
# NMF Тема: 0
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: Grand Caratt / Герметик-прокладка, силиконовый, 50 г, черный
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: не, герметик, на, хорошо, так, но, упаковка, для, всё, быстро
# Часто встречающиеся слова: не, герметик, на
# NMF Тема: 0
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: LAVR / Герметик радиатора "Стоп-течь" экспресс 310мл
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: залил, по, что, как, очиститель, очень, отличный, отлично, норм, но
# Часто встречающиеся слова: залил, по, что
# NMF Тема: 4
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: LAVR / Герметик радиатора автомобиля
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: не, течь, работает, радиатор, на, всё, отлично, инструкции, помог, ещё
# Часто встречающиеся слова: не, течь, работает
# NMF Тема: 9
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: LAVR / Индикатор утечек системы охлаждения авто
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: не, течь, радиатор, всё, работает, пришло, инструкции, помог, все, спасибо
# Часто встречающиеся слова: не, течь, радиатор
# NMF Тема: 9
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: LAVR / Холодная сварка Быстрая сталь MetalFIX 60г
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: все, что, как, по, очиститель, очень, отличный, отлично, норм, но
# Часто встречающиеся слова: все, что, как
# NMF Тема: 3
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: LIQUI MOLY / Герметик радиатора 1997 250мл
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: не, залил, течь, радиатор, на, через, все, как, работает, герметик
# Часто встречающиеся слова: не, залил, течь
# NMF Тема: 6
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: Senfineco / Герметик автомобильный
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: герметик, хороший, спасибо, быстро, отличный, упаковано, рекомендую, для, советую, хорошо
# Часто встречающиеся слова: герметик, хороший, спасибо
# NMF Тема: 1
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
#
#
# Товар: Деталька / Герметик прокладок силиконовый 70мл VICTOR REINZ
# Ключевая мысль: Основные характеристики товара:
# Ключевые слова: хороший, не, герметик, так, раз, за, советую, все, хорошо, как
# Часто встречающиеся слова: хороший, не, герметик
# NMF Тема: 7
# Sentiment: Нейтральный
# Положительные аспекты:
# Отрицательные аспекты:
